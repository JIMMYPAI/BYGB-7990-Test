# %% [markdown]
# ## Lab 2 - Stemming and Part of Speech Tagging with NLTK

# %% [markdown]
# Today we will build upon what we learned last week concerning frequency distributions to utilize stemming and part of speech (POS) taggers.
#
# Stemming is the process for reducing words to their word stem, base or root form. For example, the result of stemming the words “kicker,” “kicked” and “kicking” is “kick.”
#
# The process of classifying words into their parts of speech and labeling them accordingly is known as part-of-speech tagging, POS-tagging, or simply tagging. Parts of speech are also known as word classes or lexical categories. The collection of tags used for a particular task is known as a tagset.
#
# A part-of-speech tagger, or POS-tagger, processes a sequence of words, and attaches a part of speech tag to each word.
#
# We’ll be tagging words in the input file as these types of nouns, among other tags:
#
# - NN: Noun, singular or mass
# - NNP: Proper noun, singular
# - NNS: Noun, plural
# - NNPS: Proper noun, plural
#
# You can find a comprehensive list of POS abbrevations and their meanings here: (https://cs.nyu.edu/grishman/jet/guide/PennPOS.html).

# %% [markdown]
# ### Preliminary Steps

# %%
#run it if you haven't install NLTK already
# !pip install nltk

# %%
import nltk 
from nltk.corpus import stopwords
from nltk import FreqDist

# %%
f = open('input new.txt','rb')
raw = f.read()
raw = raw.decode("utf-8")
raw = raw.replace('\n',' ')

# %%
#Tokenization
tokens = nltk.word_tokenize(raw)

#Stopwords Removal and only keep text data then change to lowercase
mystopwords = stopwords.words('english')
words = [w.lower() for w in tokens if w.isalpha() if w.lower()not in mystopwords]

# %%
tokens
# Out:
# ['0|0|5|The',
#  'Canon',
#  'Rebel',
#  'T3i',
#  'takes',
#  'the',
#  'consumer',
#  'level',
#  'dSLR',
#  'a',
#  'couple',
#  'steps',
#  'closer',
#  'to',
#  'the',
#  'mid-level',
#  'Canon',
#  '60D',
#  'with',
#  'the',
#  'addition',
#  'of',
#  'the',
#  'rotating',
#  'rear',
#  'LCD',
#  'screen',
#  ',',
#  'remote',
#  'flash',
#  'firing',
#  ',',
#  'and',
#  'in-camera',
#  'processing',
#  'features',
#  '.',
#  'The',
#  'already',
#  'highly',
#  'competent',
#  ',',
#  'older',
#  'Rebel',
#  'T2i',
#  'already',
#  'shared',
#  'many',
#  'important',
#  'features',
#  'with',
#  'the',
#  '60D',
#  '(',
#  'and',
#  'even',
#  'features',
#  'of',
#  'the',
#  'semi-pro',
#  '7D',
#  ')',
#  'including',
#  'the',
#  '18',
#  'MP',
#  'sensor',
#  ',',
#  '63-zone',
#  'exposure',
#  'metering',
#  'system',
#  ',',
#  'high',
#  'ISO',
#  'performance',
#  ',',
#  'HD',
#  'movie',
#  'capabilities',
#  ',',
#  'and',
#  'Digic',
#  '4',
#  'image',
#  'processor',
#  '.',
#  'With',
#  'these',
#  'new',
#  'upgrades',
#  ',',
#  'it',
#  'might',
#  'make',
#  'it',
#  'even',
#  'more',
#  'difficult',
#  'to',
#  'choose',
#  'between',
#  'them',
#  '.',
#  'But',
#  'there',
#  'are',
#  'some',
#  'important',
#  'differences',
#  '.',
#  'If',
#  'you',
#  'are',
#  'considering',
#  'the',
#  'Rebel',
#  'T3i',
#  'vs',
#  'T2i',
#  ',',
#  'the',
#  'Rebel',
#  'T3i',
#  'is',
#  'replacing',
#  'the',
#  'T2i',
#  '.',
#  'Since',
#  'both',
#  'cameras',
#  'share',
#  'the',
#  'same',
#  '18',
#  'megapixel',
#  'sensor',
#  'and',
#  'Digic',
#  '4',
#  'processor',
#  ',',
#  'both',
#  'the',
#  'T2i',
#  'and',
#  'T3i',
#  'will',
#  'create',
#  'images',
#  'with',
#  'exactly',
#  'the',
#  'same',
#  'image',
#  'quality',
#  ',',
#  'produce',
#  'the',
#  'same',
#  'low',
#  'light/',
#  'high',
#  'ISO',
#  'performance',
#  ',',
#  'shoot',
#  'at',
#  '3.7',
#  'frames',
#  'per',
#  'second',
#  ',',
#  'and',
#  'have',
#  'nearly',
#  'the',
#  'same',
#  'size',
#  'and',
#  'build',
#  'quality',
#  '.',
#  'They',
#  'are',
#  'both',
#  'offered',
#  'with',
#  'the',
#  'same',
#  '18-55mm',
#  'kit',
#  'lens',
#  '(',
#  'with',
#  'some',
#  'minor',
#  'cosmetic',
#  'differences',
#  'on',
#  'the',
#  'new',
#  'T3i',
#  'kit',
#  'lens',
#  ')',
#  '.',
#  'The',
#  'T3i',
#  'is',
#  'very',
#  'slightly',
#  'larger',
#  'and',
#  'heavier',
#  'due',
#  'to',
#  'the',
#  'addition',
#  'of',
#  'the',
#  'rotating',
#  'rear',
#  'LCD',
#  'monitor',
#  '.',
#  'And',
#  'that',
#  'is',
#  'one',
#  'of',
#  'the',
#  'biggest',
#  'differences',
#  'between',
#  'the',
#  'two',
#  'cameras',
#  '.',
#  'Do',
#  'you',
#  'want',
#  'and',
#  'need',
#  'a',
#  'vari-angle',
#  'rear',
#  'screen',
#  'or',
#  'not',
#  '?',
#  'The',
#  'other',
#  'major',
#  'difference',
#  'is',
#  'the',
#  'ability',
#  'of',
#  'the',
#  'T3i',
#  'to',
#  'remotely',
#  'control',
#  'multiple',
#  'off-camera',
#  'flashes',
#  '.',
#  'Like',
#  'the',
#  '60D',
#  'and',
#  '7D',
#  ',',
#  'you',
#  'can',
#  'use',
#  'the',
#  'built-in',
#  'flash',
#  'of',
#  'the',
#  'T3i',
#  'to',
#  'trigger',
#  'other',
#  'Canon',
#  'Speedlites',
#  '.',
#  'Some',
#  'other',
#  'minor',
#  'additions',
#  'to',
#  'the',
#  'T3i',
#  'include',
#  'the',
#  'Scene',
#  'Intelligent',
#  'Auto',
#  'Mode',
#  ',',
#  'which',
#  'is',
#  'a',
#  'feature',
#  'borrowed',
#  'from',
#  'point',
#  'and',
#  'shoot',
#  'cameras',
#  '.',
#  'When',
#  'in',
#  'Auto',
#  'mode',
#  ',',
#  'the',
#  'T3i',
#  'will',
#  'make',
#  'a',
#  'determination',
#  'of',
#  'what',
#  'type',
#  'of',
#  'scene',
#  'you',
#  'are',
#  'shooting',
#  '-',
#  'close-up',
#  ',',
#  'portrait',
#  ',',
#  'landscape',
#  ',',
#  'etc',
#  '.',
#  '-',
#  'and',
#  'automatically',
#  'configure',
#  'the',
#  'camera',
#  'settings',
#  'accordingly',
#  '.',
#  'However',
#  ',',
#  'if',
#  'you',
#  'want',
#  'to',
#  'use',
#  'a',
#  'powerful',
#  'and',
#  'costly',
#  'digital',
#  'SLR',
#  'as',
#  'a',
#  'point',
#  'and',
#  'shoot',
#  ',',
#  'you',
#  'should',
#  'probably',
#  'save',
#  'the',
#  'money',
#  'and',
#  'just',
#  'buy',
#  'a',
#  'nice',
#  ',',
#  'high',
#  'quality',
#  'point',
#  'and',
#  'shoot',
#  'like',
#  'the',
#  'Canon',
#  'S95',
#  '.',
#  'Other',
#  'additional',
#  'but',
#  'not',
#  'essential',
#  'upgrades',
#  'include',
#  'the',
#  'in-camera',
#  'processing',
#  'Creative',
#  'Filters',
#  ',',
#  'and',
#  'the',
#  'ability',
#  'to',
#  'choose',
#  'different',
#  'image',
#  'size',
#  'ratios',
#  'and',
#  'to',
#  'rate',
#  'your',
#  'images',
#  '.',
#  '(',
#  'Helpful',
#  'hint',
#  ':',
#  'press',
#  'the',
#  'Q',
#  'Button',
#  'while',
#  'in',
#  'image',
#  'playback',
#  'and',
#  'you',
#  'can',
#  'access',
#  'features',
#  'like',
#  'rating',
#  ',',
#  'rotating',
#  ',',
#  'and',
#  'Creative',
#  'Filters',
#  '.',
#  ')',
#  'There',
#  'is',
#  'also',
#  'a',
#  'marginally',
#  'helpful',
#  'Feature',
#  'Guide',
#  'which',
#  'gives',
#  'brief',
#  'descriptions',
#  'of',
#  'various',
#  'settings',
#  'and',
#  'some',
#  'additional',
#  'video',
#  'features',
#  'like',
#  'Video',
#  'Snapshot',
#  ',',
#  'which',
#  'you',
#  'can',
#  'use',
#  'to',
#  'shoot',
#  'short',
#  'video',
#  'clips',
#  'that',
#  'are',
#  'automatically',
#  'joined',
#  'together',
#  'into',
#  'a',
#  'video',
#  ',',
#  'with',
#  'music',
#  '.',
#  'Canon',
#  'Rebel',
#  'T3i',
#  'vs.',
#  '60D',
#  'vs.',
#  '7D',
#  'Sensor',
#  'and',
#  'Image',
#  'Quality',
#  ':',
#  'All',
#  'three',
#  'cameras',
#  'share',
#  'a',
#  'very',
#  'similar',
#  'sensor',
#  'and',
#  '18',
#  'megapixels',
#  ',',
#  'and',
#  'so',
#  'their',
#  'image',
#  'quality',
#  'will',
#  'be',
#  'virtually',
#  'the',
#  'same',
#  '.',
#  'All',
#  'are',
#  'capable',
#  'of',
#  'taking',
#  'professional',
#  'quality',
#  'images',
#  '.',
#  'Exposure',
#  'Metering',
#  ':',
#  'The',
#  'three',
#  'cameras',
#  'all',
#  'share',
#  'the',
#  'latest',
#  '63-zone',
#  ',',
#  'dual-layer',
#  'exposure',
#  'metering',
#  'system',
#  'and',
#  '4',
#  'metering',
#  'modes',
#  '.',
#  'That',
#  'means',
#  'they',
#  'will',
#  'all',
#  'determine',
#  'the',
#  'exposure',
#  'virtually',
#  'identically',
#  'and',
#  'enable',
#  'you',
#  'to',
#  'take',
#  'properly',
#  'exposed',
#  'photos',
#  'in',
#  'most',
#  'every',
#  'situation',
#  ',',
#  'including',
#  'difficult',
#  'back-lit',
#  'scenes',
#  '.',
#  'The',
#  'size',
#  'of',
#  'the',
#  'areas',
#  'metered',
#  'for',
#  'Partial',
#  'and',
#  'Spot',
#  'metering',
#  'vary',
#  'slightly',
#  'between',
#  'the',
#  'cameras',
#  ',',
#  'but',
#  'that',
#  'is',
#  "n't",
#  'anything',
#  'critical',
#  '.',
#  'Autofocus',
#  ':',
#  'The',
#  'T3i',
#  'shares',
#  'a',
#  'similar',
#  'autofocus',
#  'system',
#  'to',
#  'the',
#  '60D',
#  ',',
#  'with',
#  '9',
#  'focus',
#  'points',
#  'and',
#  'three',
#  'auto',
#  'focusing',
#  'modes',
#  '.',
#  'However',
#  'the',
#  '9',
#  'AF',
#  'points',
#  'of',
#  'the',
#  '60D',
#  'are',
#  'more',
#  'sensitive',
#  'than',
#  'those',
#  'of',
#  'the',
#  'T3i',
#  ':',
#  'all',
#  'are',
#  'cross-type',
#  'in',
#  'the',
#  '60D',
#  ',',
#  'only',
#  'the',
#  'center',
#  'is',
#  'cross-type',
#  'in',
#  'the',
#  'T3i',
#  '.',
#  'The',
#  '60D',
#  'autofocus',
#  'system',
#  'is',
#  'much',
#  'less',
#  'complex',
#  'than',
#  'the',
#  'sophisticated',
#  'AF',
#  'system',
#  'of',
#  'the',
#  '7D',
#  'with',
#  'its',
#  '19',
#  'AF',
#  'point',
#  'system',
#  'and',
#  'its',
#  'additional',
#  'Zone',
#  ',',
#  'Spot',
#  ',',
#  'and',
#  'Expansion',
#  'focus',
#  'modes',
#  '.',
#  'These',
#  'various',
#  'modes',
#  'address',
#  'how',
#  'you',
#  'want',
#  'to',
#  'deal',
#  'with',
#  'and',
#  'group',
#  'the',
#  'numerous',
#  'AF',
#  'points',
#  '.',
#  'Plus',
#  'the',
#  'custom',
#  'settings',
#  'of',
#  'the',
#  '7D',
#  'allow',
#  'one',
#  'to',
#  'customize',
#  'how',
#  'the',
#  'AF',
#  'system',
#  'works',
#  '-',
#  'how',
#  'it',
#  'tracks',
#  'subjects',
#  ',',
#  'how',
#  'it',
#  'deals',
#  'with',
#  'objects',
#  'that',
#  'come',
#  'between',
#  'you',
#  'and',
#  'your',
#  'initial',
#  'subject',
#  ',',
#  'how',
#  'quickly',
#  'it',
#  'responds',
#  'to',
#  'these',
#  'changes',
#  'of',
#  'possible',
#  'subjects',
#  'that',
#  'are',
#  'at',
#  'different',
#  'distances',
#  'from',
#  'you',
#  ',',
#  'etc',
#  '.',
#  'However',
#  ',',
#  'if',
#  'you',
#  'are',
#  'not',
#  'an',
#  'avid',
#  'sports',
#  'photographer',
#  ',',
#  'a',
#  'wildlife',
#  'shooter',
#  ',',
#  'or',
#  'someone',
#  'who',
#  'understands',
#  ',',
#  'needs',
#  ',',
#  'and',
#  'will',
#  'use',
#  'the',
#  'elaborate',
#  'features',
#  'of',
#  'the',
#  '7D',
#  'AF',
#  'system',
#  ',',
#  'then',
#  'this',
#  'should',
#  "n't",
#  'sway',
#  'you',
#  '.',
#  'Construction',
#  ':',
#  'As',
#  'you',
#  'can',
#  'probably',
#  'figure',
#  'out',
#  'from',
#  'the',
#  'prices',
#  ',',
#  'each',
#  'camera',
#  'is',
#  'not',
#  'built',
#  'the',
#  'same',
#  '.',
#  'The',
#  'T3i',
#  'has',
#  'relatively',
#  'strong',
#  'construction',
#  'of',
#  'a',
#  'stainless',
#  'steel',
#  'frame',
#  'with',
#  'polycarbonate',
#  'body',
#  '.',
#  'The',
#  '60D',
#  'has',
#  'a',
#  'stronger',
#  'and',
#  'lighter',
#  'aluminum',
#  'frame',
#  'and',
#  'polycarbonate',
#  'body',
#  ',',
#  'but',
#  'not',
#  'as',
#  'strong',
#  'as',
#  'the',
#  '7D',
#  "'s",
#  'magnesium',
#  'alloy',
#  'construction',
#  '.',
#  'The',
#  '60D',
#  'also',
#  'has',
#  'some',
#  'amount',
#  'of',
#  'weather',
#  'sealing',
#  '-',
#  'more',
#  'than',
#  'the',
#  'T3i',
#  ',',
#  'less',
#  'than',
#  'the',
#  '7D',
#  '.',
#  'But',
#  'for',
#  'most',
#  'users',
#  ',',
#  'including',
#  'even',
#  'those',
#  'using',
#  'the',
#  'camera',
#  'daily',
#  'or',
#  'in',
#  'travel',
#  'situations',
#  ',',
#  'the',
#  'construction',
#  'of',
#  'any',
#  'of',
#  'these',
#  'cameras',
#  'is',
#  'far',
#  'more',
#  'than',
#  'good',
#  'enough',
#  ',',
#  'strong',
#  'enough',
#  ',',
#  'and',
#  'durable',
#  'enough',
#  '.',
#  'ISO',
#  ':',
#  'Since',
#  'they',
#  'all',
#  'share',
#  'a',
#  'very',
#  'similar',
#  'sensor',
#  ',',
#  'the',
#  'ISO',
#  'sensitivity',
#  'and',
#  'performance',
#  'at',
#  'high',
#  'ISO',
#  'settings',
#  'is',
#  'virtually',
#  'the',
#  'same',
#  'for',
#  'these',
#  'three',
#  'cameras',
#  '.',
#  'But',
#  'do',
#  "n't",
#  'take',
#  'my',
#  'word',
#  'for',
#  'it',
#  ',',
#  'do',
#  "n't",
#  'be',
#  'swayed',
#  'by',
#  'pixel',
#  'peepers',
#  'on',
#  'forums',
#  ',',
#  'instead',
#  'check',
#  'out',
#  'the',
#  'camera',
#  'sensor',
#  'tests',
#  'at',
#  'dxomark',
#  'to',
#  'verify',
#  'this',
#  '.',
#  'As',
#  'you',
#  'can',
#  'see',
#  ',',
#  'they',
#  'all',
#  ...]

# %% [markdown]
# ### Stemming

# %% [markdown]
# 1. Porter Stemmer

# %%
#Use Porter Stemmer 
porter = nltk.PorterStemmer()
stem1 = [porter.stem(w) for w in words]

#Encode with utf-8
stem1 = [w for w in stem1]

#Get the frequency distribution 
freq1 = FreqDist(stem1)
#Sort the result
sorted_freq1 = sorted(freq1.items(),key = lambda k: k[1], reverse = True)

# %%
sorted_freq1
# Out:
# [('camera', 647),
#  ('video', 246),
#  ('use', 244),
#  ('canon', 212),
#  ('pictur', 186),
#  ('take', 157),
#  ('shoot', 157),
#  ('great', 155),
#  ('len', 146),
#  ('get', 133),
#  ('qualiti', 126),
#  ('dslr', 123),
#  ('like', 114),
#  ('would', 108),
#  ('want', 105),
#  ('good', 104),
#  ('one', 101),
#  ('imag', 100),
#  ('set', 97),
#  ('featur', 87),
#  ('mode', 86),
#  ('batteri', 84),
#  ('screen', 80),
#  ('love', 80),
#  ('shot', 78),
#  ('also', 76),
#  ('need', 74),
#  ('go', 74),
#  ('photo', 71),
#  ('time', 70),
#  ('realli', 67),
#  ('new', 66),
#  ('still', 66),
#  ('better', 66),
#  ('first', 63),
#  ('manual', 62),
#  ('look', 62),
#  ('work', 61),
#  ('learn', 60),
#  ('easi', 59),
#  ('thing', 58),
#  ('well', 58),
#  ('recommend', 58),
#  ('even', 57),
#  ('flash', 55),
#  ('point', 55),
#  ('make', 53),
#  ('card', 53),
#  ('hd', 51),
#  ('kit', 51),
#  ('buy', 51),
#  ('much', 51),
#  ('photograph', 51),
#  ('review', 51),
#  ('light', 51),
#  ('lcd', 50),
#  ('differ', 50),
#  ('price', 50),
#  ('record', 49),
#  ('purchas', 49),
#  ('lens', 48),
#  ('say', 48),
#  ('control', 47),
#  ('auto', 46),
#  ('nice', 46),
#  ('eo', 46),
#  ('photographi', 46),
#  ('bought', 46),
#  ('function', 45),
#  ('rebel', 44),
#  ('movi', 44),
#  ('best', 44),
#  ('lot', 43),
#  ('digit', 42),
#  ('see', 42),
#  ('amaz', 42),
#  ('got', 42),
#  ('nikon', 42),
#  ('slr', 41),
#  ('far', 41),
#  ('low', 39),
#  ('focu', 39),
#  ('iso', 38),
#  ('give', 38),
#  ('come', 38),
#  ('feel', 38),
#  ('high', 37),
#  ('right', 37),
#  ('view', 35),
#  ('littl', 35),
#  ('back', 35),
#  ('button', 34),
#  ('zoom', 34),
#  ('amazon', 34),
#  ('mani', 33),
#  ('profession', 33),
#  ('without', 33),
#  ('captur', 33),
#  ('could', 33),
#  ('howev', 32),
#  ('sinc', 31),
#  ('help', 31),
#  ('experi', 31),
#  ('know', 31),
#  ('sensor', 30),
#  ('chang', 30),
#  ('menu', 30),
#  ('life', 30),
#  ('money', 29),
#  ('full', 29),
#  ('read', 29),
#  ('day', 29),
#  ('around', 29),
#  ('level', 28),
#  ('http', 28),
#  ('start', 28),
#  ('compar', 28),
#  ('enough', 27),
#  ('pro', 27),
#  ('var', 27),
#  ('allow', 26),
#  ('bodi', 26),
#  ('year', 26),
#  ('definit', 26),
#  ('may', 25),
#  ('abl', 25),
#  ('find', 25),
#  ('excel', 25),
#  ('clear', 25),
#  ('month', 25),
#  ('never', 25),
#  ('includ', 24),
#  ('frame', 24),
#  ('rate', 24),
#  ('everi', 24),
#  ('big', 24),
#  ('improv', 24),
#  ('rang', 24),
#  ('awesom', 24),
#  ('came', 24),
#  ('system', 23),
#  ('upgrad', 23),
#  ('autofocu', 23),
#  ('option', 23),
#  ('hand', 23),
#  ('extern', 23),
#  ('someth', 23),
#  ('sure', 23),
#  ('think', 23),
#  ('product', 23),
#  ('capabl', 22),
#  ('consid', 22),
#  ('result', 22),
#  ('adjust', 22),
#  ('ever', 22),
#  ('took', 22),
#  ('went', 22),
#  ('model', 22),
#  ('taken', 22),
#  ('ca', 22),
#  ('research', 22),
#  ('reason', 22),
#  ('two', 21),
#  ('power', 21),
#  ('deal', 21),
#  ('user', 21),
#  ('speed', 21),
#  ('beginn', 21),
#  ('alway', 21),
#  ('found', 21),
#  ('tri', 21),
#  ('subject', 20),
#  ('expens', 20),
#  ('viewfind', 20),
#  ('pretti', 20),
#  ('fast', 20),
#  ('pic', 20),
#  ('though', 20),
#  ('live', 20),
#  ('perfect', 20),
#  ('decid', 20),
#  ('way', 20),
#  ('second', 19),
#  ('monitor', 19),
#  ('abil', 19),
#  ('automat', 19),
#  ('world', 19),
#  ('memori', 19),
#  ('grip', 19),
#  ('long', 19),
#  ('made', 19),
#  ('cmo', 19),
#  ('own', 19),
#  ('everyth', 19),
#  ('addit', 18),
#  ('less', 18),
#  ('oper', 18),
#  ('angl', 18),
#  ('continu', 18),
#  ('film', 18),
#  ('upload', 18),
#  ('seem', 18),
#  ('mic', 18),
#  ('anyon', 18),
#  ('alreadi', 17),
#  ('highli', 17),
#  ('size', 17),
#  ('anoth', 17),
#  ('plan', 17),
#  ('keep', 17),
#  ('away', 17),
#  ('color', 17),
#  ('beauti', 17),
#  ('problem', 17),
#  ('swivel', 17),
#  ('effect', 17),
#  ('end', 17),
#  ('said', 17),
#  ('offer', 16),
#  ('save', 16),
#  ('creativ', 16),
#  ('af', 16),
#  ('moment', 16),
#  ('sharp', 16),
#  ('almost', 16),
#  ('tell', 16),
#  ('last', 16),
#  ('wonder', 16),
#  ('happi', 16),
#  ('audio', 16),
#  ('expect', 16),
#  ('soni', 16),
#  ('scene', 15),
#  ('probabl', 15),
#  ('filter', 15),
#  ('short', 15),
#  ('plu', 15),
#  ('custom', 15),
#  ('quickli', 15),
#  ('bright', 15),
#  ('quit', 15),
#  ('microphon', 15),
#  ('pick', 15),
#  ('invest', 15),
#  ('pleas', 15),
#  ('fantast', 15),
#  ('close', 15),
#  ('play', 15),
#  ('con', 15),
#  ('part', 15),
#  ('person', 15),
#  ('class', 15),
#  ('flip', 15),
#  ('worth', 15),
#  ('resolut', 15),
#  ('exposur', 14),
#  ('situat', 14),
#  ('test', 14),
#  ('quick', 14),
#  ('move', 14),
#  ('issu', 14),
#  ('busi', 14),
#  ('requir', 14),
#  ('star', 14),
#  ('impress', 14),
#  ('extra', 14),
#  ('remot', 13),
#  ('import', 13),
#  ('perform', 13),
#  ('digic', 13),
#  ('processor', 13),
#  ('access', 13),
#  ('advanc', 13),
#  ('easili', 13),
#  ('yet', 13),
#  ('larg', 13),
#  ('turn', 13),
#  ('return', 13),
#  ('higher', 13),
#  ('small', 13),
#  ('especi', 13),
#  ('peopl', 13),
#  ('although', 13),
#  ('detail', 13),
#  ('choic', 13),
#  ('wait', 13),
#  ('absolut', 13),
#  ('nsprefix', 13),
#  ('per', 12),
#  ('three', 12),
#  ('anyth', 12),
#  ('understand', 12),
#  ('pixel', 12),
#  ('top', 12),
#  ('wireless', 12),
#  ('fp', 12),
#  ('kid', 12),
#  ('basic', 12),
#  ('famili', 12),
#  ('real', 12),
#  ('glad', 12),
#  ('line', 12),
#  ('wish', 12),
#  ('raw', 12),
#  ('thought', 12),
#  ('box', 12),
#  ('compact', 12),
#  ('ship', 12),
#  ('bit', 12),
#  ('els', 12),
#  ('wife', 12),
#  ('meter', 11),
#  ('megapixel', 11),
#  ('guid', 11),
#  ('show', 11),
#  ('dial', 11),
#  ('extrem', 11),
#  ('hold', 11),
#  ('shutter', 11),
#  ('unless', 11),
#  ('sound', 11),
#  ('leav', 11),
#  ('least', 11),
#  ('felt', 11),
#  ('friend', 11),
#  ('put', 11),
#  ('spend', 11),
#  ('enjoy', 11),
#  ('gener', 11),
#  ('valu', 11),
#  ('disappoint', 11),
#  ('head', 11),
#  ('bad', 11),
#  ('might', 10),
#  ('due', 10),
#  ('major', 10),
#  ('clip', 10),
#  ('amount', 10),
#  ('instead', 10),
#  ('overal', 10),
#  ('direct', 10),
#  ('fix', 10),
#  ('tripod', 10),
#  ('actual', 10),
#  ('sd', 10),
#  ('cours', 10),
#  ('care', 10),
#  ('interfac', 10),
#  ('huge', 10),
#  ('updat', 10),
#  ('longer', 10),
#  ('free', 10),
#  ('week', 10),
#  ('fine', 10),
#  ('brand', 10),
#  ('call', 10),
#  ('stabil', 10),
#  ('cheap', 10),
#  ('util', 10),
#  ('inch', 10),
#  ('accur', 10),
#  ('fun', 10),
#  ('chose', 10),
#  ('complaint', 10),
#  ('enhanc', 10),
#  ('rear', 9),
#  ('share', 9),
#  ('mp', 9),
#  ('produc', 9),
#  ('type', 9),
#  ('etc', 9),
#  ('variou', 9),
#  ('similar', 9),
#  ('mean', 9),
#  ('balanc', 9),
#  ('place', 9),
#  ('often', 9),
#  ('open', 9),
#  ('home', 9),
#  ('minut', 9),
#  ('eye', 9),
#  ('switch', 9),
#  ('left', 9),
#  ('indoor', 9),
#  ('whole', 9),
#  ('hope', 9),
#  ('amateur', 9),
#  ('sever', 9),
#  ('nois', 9),
#  ('thank', 9),
#  ('let', 9),
#  ('fit', 9),
#  ('easier', 9),
#  ('prefer', 9),
#  ('apertur', 9),
#  ('fact', 9),
#  ('accessori', 9),
#  ('field', 9),
#  ('ago', 9),
#  ('provid', 9),
#  ('faster', 9),
#  ('son', 9),
#  ('bottom', 9),
#  ('stop', 9),
#  ('packag', 9),
#  ('mark', 9),
#  ('v', 9),
#  ('choos', 8),
#  ('creat', 8),
#  ('nearli', 8),
#  ('larger', 8),
#  ('portrait', 8),
#  ('snapshot', 8),
#  ('construct', 8),
#  ('figur', 8),
#  ('built', 8),
#  ('white', 8),
#  ('walk', 8),
#  ('articul', 8),
#  ('notic', 8),
#  ('note', 8),
#  ('camcord', 8),
#  ('rather', 8),
#  ('eas', 8),
#  ('knew', 8),
#  ('seen', 8),
#  ('sometim', 8),
#  ('previou', 8),
#  ('display', 8),
#  ('standard', 8),
#  ('stuff', 8),
#  ('edit', 8),
#  ('add', 8),
#  ('frequent', 8),
#  ('sdhc', 8),
#  ('seri', 8),
#  ('event', 8),
#  ('version', 8),
#  ('softwar', 8),
#  ('avail', 8),
#  ('job', 8),
#  ('purpos', 8),
#  ('slow', 8),
#  ('except', 8),
#  ('cheaper', 8),
#  ('opinion', 8),
#  ('im', 8),
#  ('tamron', 8),
#  ('complet', 8),
#  ('h', 8),
#  ('step', 7),
#  ('rotat', 7),
#  ('process', 7),
#  ('difficult', 7),
#  ('intellig', 7),
#  ('sport', 7),
#  ('rel', 7),
#  ('lighter', 7),
#  ('travel', 7),
#  ('begin', 7),
#  ('macro', 7),
#  ('wo', 7),
#  ('smaller', 7),
#  ('weight', 7),
#  ('parti', 7),
#  ('design', 7),
#  ('seriou', 7),
#  ('desir', 7),
#  ('simpl', 7),
#  ('next', 7),
#  ('true', 7),
#  ('blown', 7),
#  ('entri', 7),
#  ('compat', 7),
#  ('common', 7),
#  ('hard', 7),
#  ('gave', 7),
#  ('face', 7),
#  ('truli', 7),
#  ('annoy', 7),
#  ('surpris', 7),
#  ('select', 7),
#  ('photoshop', 7),
#  ('necessari', 7),
#  ('youtub', 7),
#  ('search', 7),
#  ('side', 7),
#  ('order', 7),
#  ('old', 7),
#  ('recent', 7),
#  ('onlin', 7),
#  ('realiz', 7),
#  ('ii', 7),
#  ('must', 7),
#  ('cost', 7),
#  ('mine', 7),
#  ('wide', 7),
#  ('rememb', 7),
#  ('x', 7),
#  ('maximum', 7),
#  ('sorri', 7),
#  ('soon', 7),
#  ('crop', 7),
#  ('wed', 7),
#  ('ye', 7),
#  ('daughter', 7),
#  ('curv', 7),
#  ('coupl', 6),
#  ('replac', 6),
#  ('exactli', 6),
#  ('multipl', 6),
#  ('playback', 6),
#  ('focus', 6),
#  ('object', 6),
#  ('someon', 6),
#  ('check', 6),
#  ('current', 6),
#  ('videograph', 6),
#  ('action', 6),
#  ('case', 6),
#  ('touch', 6),
#  ('typic', 6),
#  ('plug', 6),
#  ('intuit', 6),
#  ('mom', 6),
#  ('gotten', 6),
#  ('becom', 6),
#  ('favorit', 6),
#  ('usual', 6),
#  ('snap', 6),
#  ('footag', 6),
#  ('normal', 6),
#  ('us', 6),
#  ('comput', 6),
#  ('within', 6),
#  ('charg', 6),
#  ('run', 6),
#  ('awar', 6),
#  ('via', 6),
#  ('final', 6),
#  ('finish', 6),
#  ('outdoor', 6),
#  ('readi', 6),
#  ('superb', 6),
#  ('posit', 6),
#  ('interest', 6),
#  ('receiv', 6),
#  ('write', 6),
#  ('struggl', 6),
#  ('glass', 6),
#  ('comfort', 6),
#  ('grant', 6),
#  ('afford', 6),
#  ('noth', 6),
#  ('saw', 6),
#  ('talk', 6),
#  ('handi', 6),
#  ('particularli', 6),
#  ('ad', 6),
#  ('exampl', 6),
#  ('simpli', 6),
#  ('extend', 6),
#  ('limit', 6),
#  ('aspect', 6),
#  ('file', 6),
#  ('main', 6),
#  ('night', 6),
#  ('decis', 6),
#  ('anyway', 6),
#  ('carri', 6),
#  ('guess', 6),
#  ('number', 6),
#  ('ef', 6),
#  ('heavi', 6),
#  ('base', 6),
#  ('ask', 6),
#  ('gift', 6),
#  ('tax', 6),
#  ('flexibl', 6),
#  ('expand', 6),
#  ('clariti', 6),
#  ('swflocat', 6),
#  ('movieid', 6),
#  ('consum', 5),
#  ('older', 5),
#  ('minor', 5),
#  ('trigger', 5),
#  ('press', 5),
#  ('enabl', 5),
#  ('center', 5),
#  ('possibl', 5),
#  ('tv', 5),
#  ('master', 5),
#  ('finder', 5),
#  ('store', 5),
#  ('rest', 5),
#  ('channel', 5),
#  ('confus', 5),
#  ('dedic', 5),
#  ('everywher', 5),
#  ('pull', 5),
#  ('grow', 5),
#  ('consider', 5),
#  ('amazingli', 5),
#  ('materi', 5),
#  ('sort', 5),
#  ('worri', 5),
#  ('practic', 5),
#  ('arriv', 5),
#  ('adapt', 5),
#  ('follow', 5),
#  ('natur', 5),
#  ('honestli', 5),
#  ('specif', 5),
#  ('flower', 5),
#  ('item', 5),
#  ('solid', 5),
#  ('hesit', 5),
#  ('sell', 5),
#  ('other', 5),
#  ('question', 5),
#  ('wrong', 5),
#  ('iii', 5),
#  ('attach', 5),
#  ('cabl', 5),
#  ('regular', 5),
#  ('suggest', 5),
#  ('skill', 5),
#  ('progress', 5),
#  ('experienc', 5),
#  ('stun', 5),
#  ('skin', 5),
#  ('owner', 5),
#  ('lower', 5),
#  ('whether', 5),
#  ('mention', 5),
#  ('input', 5),
#  ('termin', 5),
#  ('crisp', 5),
#  ('singl', 5),
#  ('laptop', 5),
#  ('lack', 5),
#  ('outstand', 5),
#  ('lose', 5),
#  ('equip', 5),
#  ('tone', 5),
#  ('sold', 5),
#  ('everyon', 5),
#  ('done', 5),
#  ('beat', 5),
#  ('dim', 5),
#  ('devic', 5),
#  ('olympu', 5),
#  ('technolog', 5),
#  ('market', 5),
#  ('studio', 5),
#  ('inform', 5),
#  ('children', 5),
#  ('mbp', 5),
#  ('either', 5),
#  ('complain', 5),
#  ('mind', 5),
#  ('approxim', 5),
#  ('format', 5),
#  ('guy', 5),
#  ('swfwidth', 5),
#  ('swfheight', 5),
#  ('swfparam', 5),
#  ('flashparam', 5),
#  ('embedattribut', 5),
#  ('vacat', 5),
#  ('servic', 5),
#  ('sit', 5),
#  ('rebat', 5),
#  ('fire', 4),
#  ('vs', 4),
#  ('slightli', 4),
#  ('speedlit', 4),
#  ('landscap', 4),
#  ('q', 4),
#  ('descript', 4),
#  ('area', 4),
#  ('group', 4),
#  ('distanc', 4),
#  ('strong', 4),
#  ('exact', 4),
#  ('complic', 4),
#  ('thumb', 4),
#  ('program', 4),
#  ('av', 4),
#  ('tweak', 4),
#  ('creation', 4),
#  ('electron', 4),
#  ('coverag', 4),
#  ('lock', 4),
#  ('game', 4),
#  ('pc', 4),
#  ('expert', 4),
#  ('opportun', 4),
#  ('decent', 4),
#  ('stay', 4),
#  ('constantli', 4),
#  ('click', 4),
#  ('delay', 4),
#  ('toddler', 4),
#  ('goe', 4),
#  ('husband', 4),
#  ('account', 4),
#  ('later', 4),
#  ('charger', 4),
#  ('challeng', 4),
#  ('bulki', 4),
#  ('soft', 4),
#  ('total', 4),
#  ('stick', 4),
#  ('bag', 4),
#  ('mega', 4),
#  ('intermedi', 4),
#  ('jpeg', 4),
#  ('mainli', 4),
#  ('comment', 4),
#  ('link', 4),
#  ('powershot', 4),
#  ('convinc', 4),
#  ('mayb', 4),
#  ('futur', 4),
#  ('upon', 4),
#  ('pay', 4),
#  ('strap', 4),
#  ('prime', 4),
#  ('dollar', 4),
#  ('third', 4),
#  ('perfectli', 4),
#  ('toward', 4),
#  ('site', 4),
#  ('lightroom', 4),
#  ('regret', 4),
#  ('jump', 4),
#  ('brother', 4),
#  ('xsi', 4),
#  ('conveni', 4),
#  ('laps', 4),
#  ('popular', 4),
#  ('thousand', 4),
#  ('push', 4),
#  ('separ', 4),
#  ('novic', 4),
#  ('tend', 4),
#  ('front', 4),
#  ('useless', 4),
#  ('reliabl', 4),
#  ('info', 4),
#  ('locat', 4),
#  ('match', 4),
#  ('unit', 4),
#  ('wear', 4),
#  ('interview', 4),
#  ('promot', 4),
#  ('stereo', 4),
#  ('motion', 4),
#  ('surprisingli', 4),
#  ('protect', 4),
#  ('length', 4),
#  ('cannon', 4),
#  ('forward', 4),
#  ('excit', 4),
#  ('stock', 4),
#  ('along', 4),
#  ('bigger', 4),
#  ('tilt', 4),
#  ('catch', 4),
#  ('usabl', 4),
#  ('highlight', 4),
#  ('prioriti', 4),
#  ('p', 4),
#  ('boy', 4),
#  ('gear', 4),
#  ('strongli', 4),
#  ('benefit', 4),
#  ('thu', 4),
#  ('born', 4),
#  ('nex', 4),
#  ('christma', 4),
#  ('pen', 4),
#  ('mostli', 4),
#  ('serv', 4),
#  ('lightweight', 4),
#  ('budget', 4),
#  ('handl', 4),
#  ('school', 4),
#  ('student', 4),
#  ('solv', 4),
#  ('starter', 4),
#  ('cool', 4),
#  ('paid', 4),
#  ('websit', 4),
#  ('crystal', 4),
#  ('gripe', 4),
#  ('layout', 4),
#  ('neck', 4),
#  ('jack', 4),
#  ('term', 4),
#  ('superior', 4),
#  ('believ', 4),
#  ('shop', 4),
#  ('flashvers', 4),
#  ('bgcolor', 4),
#  ('playervers', 4),
#  ('closer', 3),
#  ('heavier', 3),
#  ('biggest', 3),
#  ('determin', 3),
#  ('accordingli', 3),
#  ('costli', 3),
#  ('ratio', 3),
#  ('togeth', 3),
#  ('virtual', 3),
#  ('latest', 3),
#  ('ident', 3),
#  ('spot', 3),
#  ('vari', 3),
#  ('critic', 3),
#  ('sensit', 3),
#  ('sophist', 3),
#  ('initi', 3),
#  ('sway', 3),
#  ('weather', 3),
#  ('word', 3),
#  ('score', 3),
#  ('matter', 3),
#  ('correct', 3),
#  ('dark', 3),
#  ('corner', 3),
#  ('ebook', 3),
#  ('composit', 3),
#  ('visibl', 3),
#  ('respect', 3),
#  ('excess', 3),
#  ('secur', 3),
#  ('accident', 3),
#  ('kind', 3),
#  ('autofocus', 3),
#  ('sync', 3),
#  ('inspir', 3),
#  ('room', 3),
#  ('watch', 3),
#  ('friendli', 3),
#  ('tier', 3),
#  ('park', 3),
#  ('immedi', 3),
#  ('smugmug', 3),
#  ('heart', 3),
#  ('content', 3),
#  ('eat', 3),
#  ('rare', 3),
#  ('juic', 3),
#  ('pop', 3),
#  ('name', 3),
#  ('pocket', 3),
#  ('solut', 3),
#  ('onto', 3),
#  ('ground', 3),
#  ('okay', 3),
#  ('appear', 3),
#  ('hour', 3),
#  ('shut', 3),
#  ('minimum', 3),
#  ('babi', 3),
#  ('meant', 3),
#  ('blah', 3),
#  ('five', 3),
#  ('hassl', 3),
#  ('deliv', 3),
#  ('suppos', 3),
#  ('red', 3),
#  ('miss', 3),
#  ('firmwar', 3),
#  ('cover', 3),
#  ('drop', 3),
#  ('hundr', 3),
#  ('l', 3),
#  ('serious', 3),
#  ('data', 3),
#  ('idea', 3),
#  ('jpg', 3),
#  ('gb', 3),
#  ('happen', 3),
#  ('sampl', 3),
#  ('aspir', 3),
#  ('suitabl', 3),
#  ('deep', 3),
#  ('lay', 3),
#  ('setup', 3),
#  ('twist', 3),
#  ('four', 3),
#  ('effort', 3),
#  ('frustrat', 3),
#  ('spec', 3),
#  ('varieti', 3),
#  ('heard', 3),
#  ('plenti', 3),
#  ('depend', 3),
#  ('earlier', 3),
#  ('port', 3),
#  ('wall', 3),
#  ('wind', 3),
#  ('directli', 3),
#  ('hdmi', 3),
#  ('plastic', 3),
#  ('magic', 3),
#  ('elimin', 3),
#  ('support', 3),
#  ('incred', 3),
#  ('newbi', 3),
#  ('behind', 3),
#  ('past', 3),
#  ('panason', 3),
#  ('cut', 3),
#  ('half', 3),
#  ('appreci', 3),
#  ('answer', 3),
#  ('speedlight', 3),
#  ('sore', 3),
#  ('happier', 3),
#  ('hate', 3),
#  ('spent', 3),
#  ('kept', 3),
#  ('floor', 3),
#  ('tempt', 3),
#  ('toy', 3),
#  ('sigma', 3),
#  ('reflect', 3),
#  ('mirror', 3),
#  ('preset', 3),
#  ('super', 3),
#  ('cam', 3),
#  ('across', 3),
#  ('enthusiast', 3),
#  ('knowledg', 3),
#  ('gain', 3),
#  ('buyer', 3),
#  ('ultim', 3),
#  ('fulli', 3),
#  ('familiar', 3),
#  ('glanc', 3),
#  ('among', 3),
#  ('mm', 3),
#  ('techniqu', 3),
#  ('outsid', 3),
#  ('tool', 3),
#  ('bother', 3),
#  ('ok', 3),
#  ('ebay', 3),
#  ('project', 3),
#  ('black', 3),
#  ('distort', 3),
#  ('combin', 3),
#  ('hit', 3),
#  ('oh', 3),
#  ('schedul', 3),
#  ('basketbal', 3),
#  ('told', 3),
#  ('compromis', 3),
#  ('blurri', 3),
#  ('girl', 3),
#  ('xt', 3),
#  ('ton', 3),
#  ('exceed', 3),
#  ('proper', 3),
#  ('embed', 3),
#  ('filmmak', 3),
#  ('noisi', 3),
#  ('unfortun', 3),
#  ('speak', 3),
#  ('summer', 3),
#  ('intend', 3),
#  ('enlarg', 3),
#  ('million', 3),
#  ('convert', 3),
#  ('machin', 3),
#  ('opt', 3),
#  ('mac', 3),
#  ('trip', 3),
#  ('graini', 3),
#  ('copyright', 3),
#  ('buck', 3),
#  ('w', 3),
#  ('regx', 3),
#  ('ffversion', 3),
#  ('pt', 3),
#  ('elph', 3),
#  ('poor', 3),
#  ('xti', 3),
#  ('mid', 3),
#  ('break', 3),
#  ('na', 3),
#  ('shelf', 3),
#  ('drain', 3),
#  ('sentenc', 3),
#  ('industri', 3),
#  ...]

# %%
freq1.plot(30)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# 2.Lancaster Stemmer

# %%
#Steps are the same with the Porter Stemmer
lancaster = nltk.LancasterStemmer()
stem2 = [lancaster.stem(w) for w in words]
stem2 = [w for w in stem2]
freq2 = FreqDist(stem2)
sorted_freq2 = sorted(freq2.items(),key = lambda k: k[1], reverse = True)

# %%
sorted_freq2
# Out:
# [('camer', 570),
#  ('us', 283),
#  ('video', 246),
#  ('canon', 212),
#  ('pict', 186),
#  ('tak', 179),
#  ('shoot', 159),
#  ('gre', 158),
#  ('len', 146),
#  ('get', 133),
#  ('qual', 126),
#  ('lik', 114),
#  ('dslr', 108),
#  ('im', 108),
#  ('would', 108),
#  ('want', 105),
#  ('good', 104),
#  ('on', 101),
#  ('set', 97),
#  ('photograph', 97),
#  ('ev', 88),
#  ('mod', 88),
#  ('feat', 87),
#  ('real', 86),
#  ('battery', 84),
#  ('easy', 81),
#  ('screen', 80),
#  ('lov', 80),
#  ('shot', 78),
#  ('camera', 77),
#  ('also', 76),
#  ('nee', 74),
#  ('tim', 72),
#  ('photo', 71),
#  ('new', 70),
#  ('high', 67),
#  ('stil', 66),
#  ('bet', 66),
#  ('man', 64),
#  ('first', 63),
#  ('look', 62),
#  ('work', 61),
#  ('learn', 60),
#  ('light', 58),
#  ('thing', 58),
#  ('wel', 58),
#  ('recommend', 58),
#  ('flash', 55),
#  ('point', 55),
#  ('mak', 54),
#  ('buy', 54),
#  ('card', 53),
#  ('hd', 51),
#  ('kit', 51),
#  ('much', 51),
#  ('review', 51),
#  ('lcd', 50),
#  ('diff', 50),
#  ('pric', 50),
#  ('record', 49),
#  ('purchas', 49),
#  ('lens', 48),
#  ('got', 48),
#  ('say', 48),
#  ('control', 47),
#  ('nic', 47),
#  ('amaz', 47),
#  ('auto', 46),
#  ('eo', 46),
#  ('bought', 46),
#  ('funct', 45),
#  ('rebel', 44),
#  ('movy', 44),
#  ('low', 44),
#  ('abl', 44),
#  ('best', 44),
#  ('go', 43),
#  ('lot', 43),
#  ('digit', 42),
#  ('com', 42),
#  ('see', 42),
#  ('nikon', 42),
#  ('far', 41),
#  ('foc', 40),
#  ('giv', 39),
#  ('iso', 38),
#  ('feel', 38),
#  ('right', 37),
#  ('expery', 36),
#  ('slr', 35),
#  ('view', 35),
#  ('littl', 35),
#  ('back', 35),
#  ('button', 34),
#  ('zoom', 34),
#  ('amazon', 34),
#  ('many', 33),
#  ('profess', 33),
#  ('without', 33),
#  ('capt', 33),
#  ('could', 33),
#  ('produc', 32),
#  ('howev', 32),
#  ('ful', 32),
#  ('start', 32),
#  ('sens', 31),
#  ('sint', 31),
#  ('help', 31),
#  ('quick', 31),
#  ('know', 31),
#  ('going', 31),
#  ('chang', 30),
#  ('find', 30),
#  ('lif', 30),
#  ('money', 29),
#  ('fast', 29),
#  ('long', 29),
#  ('read', 29),
#  ('day', 29),
#  ('around', 29),
#  ('level', 28),
#  ('cre', 28),
#  ('big', 28),
#  ('opt', 28),
#  ('http', 28),
#  ('begin', 28),
#  ('comp', 28),
#  ('var', 28),
#  ('consid', 27),
#  ('enough', 27),
#  ('op', 27),
#  ('pro', 27),
#  ('clear', 27),
#  ('cam', 27),
#  ('allow', 26),
#  ('body', 26),
#  ('year', 26),
#  ('decid', 26),
#  ('definit', 26),
#  ('may', 25),
#  ('excel', 25),
#  ('nev', 25),
#  ('includ', 24),
#  ('cap', 24),
#  ('fram', 24),
#  ('rat', 24),
#  ('every', 24),
#  ('improv', 24),
#  ('rang', 24),
#  ('perfect', 24),
#  ('awesom', 24),
#  ('own', 24),
#  ('system', 23),
#  ('upgrad', 23),
#  ('autofoc', 23),
#  ('hand', 23),
#  ('grip', 23),
#  ('extern', 23),
#  ('someth', 23),
#  ('sur', 23),
#  ('think', 23),
#  ('fin', 23),
#  ('access', 22),
#  ('menu', 22),
#  ('result', 22),
#  ('adjust', 22),
#  ('mom', 22),
#  ('took', 22),
#  ('went', 22),
#  ('model', 22),
#  ('ca', 22),
#  ('research', 22),
#  ('reason', 22),
#  ('process', 21),
#  ('larg', 21),
#  ('two', 21),
#  ('pow', 21),
#  ('deal', 21),
#  ('spee', 21),
#  ('alway', 21),
#  ('found', 21),
#  ('autom', 20),
#  ('subject', 20),
#  ('expend', 20),
#  ('viewfind', 20),
#  ('smal', 20),
#  ('pretty', 20),
#  ('try', 20),
#  ('pic', 20),
#  ('though', 20),
#  ('liv', 20),
#  ('way', 20),
#  ('second', 19),
#  ('monit', 19),
#  ('less', 19),
#  ('world', 19),
#  ('act', 19),
#  ('mem', 19),
#  ('bas', 19),
#  ('seem', 19),
#  ('mad', 19),
#  ('cmo', 19),
#  ('happy', 19),
#  ('everyth', 19),
#  ('clos', 18),
#  ('addit', 18),
#  ('short', 18),
#  ('angl', 18),
#  ('keep', 18),
#  ('sery', 18),
#  ('film', 18),
#  ('upload', 18),
#  ('problem', 18),
#  ('mic', 18),
#  ('anyon', 18),
#  ('cheap', 18),
#  ('already', 17),
#  ('siz', 17),
#  ('off', 17),
#  ('adv', 17),
#  ('anoth', 17),
#  ('plan', 17),
#  ('continu', 17),
#  ('not', 17),
#  ('away', 17),
#  ('sharp', 17),
#  ('col', 17),
#  ('play', 17),
#  ('beauty', 17),
#  ('swivel', 17),
#  ('month', 17),
#  ('effect', 17),
#  ('end', 17),
#  ('said', 17),
#  ('expos', 16),
#  ('min', 16),
#  ('prob', 16),
#  ('sav', 16),
#  ('part', 16),
#  ('af', 16),
#  ('custom', 16),
#  ('ad', 16),
#  ('pleas', 16),
#  ('almost', 16),
#  ('tel', 16),
#  ('last', 16),
#  ('wond', 16),
#  ('audio', 16),
#  ('resolv', 16),
#  ('expect', 16),
#  ('sony', 16),
#  ('import', 15),
#  ('dig', 15),
#  ('scen', 15),
#  ('typ', 15),
#  ('filt', 15),
#  ('vary', 15),
#  ('plu', 15),
#  ('mov', 15),
#  ('bright', 15),
#  ('quit', 15),
#  ('microphon', 15),
#  ('pick', 15),
#  ('invest', 15),
#  ('fantast', 15),
#  ('tru', 15),
#  ('con', 15),
#  ('dslrs', 15),
#  ('person', 15),
#  ('class', 15),
#  ('flip', 15),
#  ('wor', 15),
#  ('situ', 14),
#  ('test', 14),
#  ('direct', 14),
#  ('issu', 14),
#  ('shut', 14),
#  ('busy', 14),
#  ('friend', 14),
#  ('requir', 14),
#  ('star', 14),
#  ('impress', 14),
#  ('remot', 13),
#  ('met', 13),
#  ('perform', 13),
#  ('yet', 13),
#  ('wireless', 13),
#  ('turn', 13),
#  ('return', 13),
#  ('espec', 13),
#  ('peopl', 13),
#  ('extr', 13),
#  ('bit', 13),
#  ('although', 13),
#  ('detail', 13),
#  ('cho', 13),
#  ('wait', 13),
#  ('absolv', 13),
#  ('nsprefix', 13),
#  ('old', 12),
#  ('per', 12),
#  ('three', 12),
#  ('anyth', 12),
#  ('understand', 12),
#  ('pixel', 12),
#  ('top', 12),
#  ('fps', 12),
#  ('kid', 12),
#  ('famy', 12),
#  ('car', 12),
#  ('glad', 12),
#  ('lin', 12),
#  ('wish', 12),
#  ('raw', 12),
#  ('stabl', 12),
#  ('thought', 12),
#  ('box', 12),
#  ('ii', 12),
#  ('compact', 12),
#  ('ship', 12),
#  ('valu', 12),
#  ('els', 12),
#  ('wif', 12),
#  ('megapixel', 11),
#  ('guid', 11),
#  ('show', 11),
#  ('dial', 11),
#  ('extrem', 11),
#  ('hold', 11),
#  ('unless', 11),
#  ('sound', 11),
#  ('leav', 11),
#  ('least', 11),
#  ('felt', 11),
#  ('surpr', 11),
#  ('spec', 11),
#  ('put', 11),
#  ('spend', 11),
#  ('enjoy', 11),
#  ('gen', 11),
#  ('acc', 11),
#  ('slow', 11),
#  ('pack', 11),
#  ('disappoint', 11),
#  ('head', 11),
#  ('bad', 11),
#  ('might', 10),
#  ('exact', 10),
#  ('due', 10),
#  ('maj', 10),
#  ('cost', 10),
#  ('clip', 10),
#  ('amount', 10),
#  ('instead', 10),
#  ('overal', 10),
#  ('bal', 10),
#  ('plac', 10),
#  ('fix', 10),
#  ('tripod', 10),
#  ('sd', 10),
#  ('cours', 10),
#  ('interfac', 10),
#  ('charg', 10),
#  ('hug', 10),
#  ('upd', 10),
#  ('am', 10),
#  ('fre', 10),
#  ('week', 10),
#  ('main', 10),
#  ('brand', 10),
#  ('cal', 10),
#  ('fact', 10),
#  ('util', 10),
#  ('inch', 10),
#  ('fun', 10),
#  ('chos', 10),
#  ('ton', 10),
#  ('complaint', 10),
#  ('enh', 10),
#  ('rear', 9),
#  ('shar', 9),
#  ('mp', 9),
#  ('near', 9),
#  ('heavy', 9),
#  ('etc', 9),
#  ('simil', 9),
#  ('mean', 9),
#  ('mat', 9),
#  ('oft', 9),
#  ('prevy', 9),
#  ('hom', 9),
#  ('minut', 9),
#  ('ey', 9),
#  ('switch', 9),
#  ('hard', 9),
#  ('left', 9),
#  ('indo', 9),
#  ('whol', 9),
#  ('hop', 9),
#  ('sev', 9),
#  ('nois', 9),
#  ('edit', 9),
#  ('necess', 9),
#  ('thank', 9),
#  ('let', 9),
#  ('fit', 9),
#  ('sit', 9),
#  ('apert', 9),
#  ('field', 9),
#  ('ago', 9),
#  ('wid', 9),
#  ('provid', 9),
#  ('son', 9),
#  ('bottom', 9),
#  ('stop', 9),
#  ('maxim', 9),
#  ('mark', 9),
#  ('serv', 9),
#  ('v', 9),
#  ('coupl', 8),
#  ('choos', 8),
#  ('portrait', 8),
#  ('snapshot', 8),
#  ('construct', 8),
#  ('fig', 8),
#  ('built', 8),
#  ('rel', 8),
#  ('men', 8),
#  ('whit', 8),
#  ('walk', 8),
#  ('artic', 8),
#  ('camcord', 8),
#  ('rath', 8),
#  ('eas', 8),
#  ('simpl', 8),
#  ('knew', 8),
#  ('seen', 8),
#  ('sometim', 8),
#  ('display', 8),
#  ('standard', 8),
#  ('stuff', 8),
#  ('frequ', 8),
#  ('sdhc', 8),
#  ('vert', 8),
#  ('pref', 8),
#  ('softw', 8),
#  ('avail', 8),
#  ('job', 8),
#  ('purpos', 8),
#  ('exceiv', 8),
#  ('opin', 8),
#  ('tamron', 8),
#  ('complet', 8),
#  ('mon', 8),
#  ('h', 8),
#  ('consum', 7),
#  ('step', 7),
#  ('rot', 7),
#  ('difficult', 7),
#  ('intellig', 7),
#  ('cent', 7),
#  ('expand', 7),
#  ('sport', 7),
#  ('travel', 7),
#  ('videograph', 7),
#  ('macro', 7),
#  ('cov', 7),
#  ('wo', 7),
#  ('excess', 7),
#  ('weight', 7),
#  ('cas', 7),
#  ('party', 7),
#  ('design', 7),
#  ('desir', 7),
#  ('next', 7),
#  ('blown', 7),
#  ('foot', 7),
#  ('entry', 7),
#  ('compat', 7),
#  ('common', 7),
#  ('solv', 7),
#  ('gav', 7),
#  ('aw', 7),
#  ('fac', 7),
#  ('annoy', 7),
#  ('ready', 7),
#  ('select', 7),
#  ('honest', 7),
#  ('photoshop', 7),
#  ('youtub', 7),
#  ('search', 7),
#  ('sid', 7),
#  ('ord', 7),
#  ('rec', 7),
#  ('onlin', 7),
#  ('must', 7),
#  ('particul', 7),
#  ('rememb', 7),
#  ('extend', 7),
#  ('x', 7),
#  ('fil', 7),
#  ('sorry', 7),
#  ('soon', 7),
#  ('crop', 7),
#  ('wed', 7),
#  ('ye', 7),
#  ('daught', 7),
#  ('curv', 7),
#  ('replac', 6),
#  ('slight', 6),
#  ('multipl', 6),
#  ('playback', 6),
#  ('focus', 6),
#  ('object', 6),
#  ('someon', 6),
#  ('check', 6),
#  ('cur', 6),
#  ('stor', 6),
#  ('touch', 6),
#  ('plug', 6),
#  ('intuit', 6),
#  ('pul', 6),
#  ('becom', 6),
#  ('const', 6),
#  ('favorit', 6),
#  ('snap', 6),
#  ('norm', 6),
#  ('comput', 6),
#  ('within', 6),
#  ('lat', 6),
#  ('run', 6),
#  ('quest', 6),
#  ('soft', 6),
#  ('via', 6),
#  ('outdo', 6),
#  ('sum', 6),
#  ('superb', 6),
#  ('posit', 6),
#  ('interest', 6),
#  ('receiv', 6),
#  ('writ', 6),
#  ('glass', 6),
#  ('ear', 6),
#  ('comfort', 6),
#  ('grant', 6),
#  ('prim', 6),
#  ('form', 6),
#  ('afford', 6),
#  ('noth', 6),
#  ('saw', 6),
#  ('talk', 6),
#  ('handy', 6),
#  ('exampl', 6),
#  ('simply', 6),
#  ('ment', 6),
#  ('loc', 6),
#  ('limit', 6),
#  ('mot', 6),
#  ('crisp', 6),
#  ('aspect', 6),
#  ('night', 6),
#  ('los', 6),
#  ('anyway', 6),
#  ('carry', 6),
#  ('guess', 6),
#  ('numb', 6),
#  ('ef', 6),
#  ('slrs', 6),
#  ('ask', 6),
#  ('gift', 6),
#  ('tax', 6),
#  ('flex', 6),
#  ('clar', 6),
#  ('swflocation', 6),
#  ('movieid', 6),
#  ('trig', 5),
#  ('press', 5),
#  ('describ', 5),
#  ('en', 5),
#  ('prop', 5),
#  ('poss', 5),
#  ('av', 5),
#  ('tv', 5),
#  ('mast', 5),
#  ('rest', 5),
#  ('channel', 5),
#  ('confus', 5),
#  ('ded', 5),
#  ('everywh', 5),
#  ('grow', 5),
#  ('sort', 5),
#  ('del', 5),
#  ('bulky', 5),
#  ('worry', 5),
#  ('pract', 5),
#  ('stick', 5),
#  ('ar', 5),
#  ('adapt', 5),
#  ('stat', 5),
#  ('follow', 5),
#  ('nat', 5),
#  ('inst', 5),
#  ('flow', 5),
#  ('item', 5),
#  ('solid', 5),
#  ('hesit', 5),
#  ('sel', 5),
#  ('techn', 5),
#  ('oth', 5),
#  ('wrong', 5),
#  ('attach', 5),
#  ('cabl', 5),
#  ('suit', 5),
#  ('regul', 5),
#  ('suggest', 5),
#  ('skil', 5),
#  ('progress', 5),
#  ('stun', 5),
#  ('skin', 5),
#  ('nov', 5),
#  ('tend', 5),
#  ('sign', 5),
#  ('wheth', 5),
#  ('rely', 5),
#  ('input', 5),
#  ('termin', 5),
#  ('mag', 5),
#  ('singl', 5),
#  ('laptop', 5),
#  ('lack', 5),
#  ('outstand', 5),
#  ('equip', 5),
#  ('pri', 5),
#  ('sold', 5),
#  ('everyon', 5),
#  ('don', 5),
#  ('beat', 5),
#  ('dim', 5),
#  ('dev', 5),
#  ('olymp', 5),
#  ('technolog', 5),
#  ('handl', 5),
#  ('market', 5),
#  ('studio', 5),
#  ('inform', 5),
#  ('childr', 5),
#  ('mbps', 5),
#  ('eith', 5),
#  ('complain', 5),
#  ('mind', 5),
#  ('approxim', 5),
#  ('mil', 5),
#  ('guy', 5),
#  ('swfwidth', 5),
#  ('swfheight', 5),
#  ('swfparams', 5),
#  ('flashparam', 5),
#  ('embedattribut', 5),
#  ('vac', 5),
#  ('reb', 5),
#  ('fir', 4),
#  ('vs', 4),
#  ('speedlit', 4),
#  ('landscap', 4),
#  ('q', 4),
#  ('id', 4),
#  ('crit', 4),
#  ('group', 4),
#  ('dist', 4),
#  ('strong', 4),
#  ('comply', 4),
#  ('thumb', 4),
#  ('program', 4),
#  ('correct', 4),
#  ('tweak', 4),
#  ('electron', 4),
#  ('vis', 4),
#  ('sec', 4),
#  ('lock', 4),
#  ('gam', 4),
#  ('kind', 4),
#  ('pc', 4),
#  ('expert', 4),
#  ('opportun', 4),
#  ('dec', 4),
#  ('stay', 4),
#  ('click', 4),
#  ('gon', 4),
#  ('delay', 4),
#  ('toddl', 4),
#  ('goe', 4),
#  ('husband', 4),
#  ('account', 4),
#  ('challeng', 4),
#  ('tot', 4),
#  ('minim', 4),
#  ('bag', 4),
#  ('meg', 4),
#  ('intermedy', 4),
#  ('jpeg', 4),
#  ('link', 4),
#  ('powershot', 4),
#  ('convint', 4),
#  ('mayb', 4),
#  ('fut', 4),
#  ('upon', 4),
#  ('pay', 4),
#  ('strap', 4),
#  ('doll', 4),
#  ('third', 4),
#  ('toward', 4),
#  ('ex', 4),
#  ('dat', 4),
#  ('lightroom', 4),
#  ('regret', 4),
#  ('jump', 4),
#  ('broth', 4),
#  ('xsi', 4),
#  ('conveny', 4),
#  ('laps', 4),
#  ('popul', 4),
#  ('thousand', 4),
#  ('push', 4),
#  ('sep', 4),
#  ('four', 4),
#  ('front', 4),
#  ('useless', 4),
#  ('info', 4),
#  ('match', 4),
#  ('unit', 4),
#  ('port', 4),
#  ('wear', 4),
#  ('interview', 4),
#  ('promot', 4),
#  ('stereo', 4),
#  ('protect', 4),
#  ('cannon', 4),
#  ('somewh', 4),
#  ('forward', 4),
#  ('excit', 4),
#  ('stock', 4),
#  ('along', 4),
#  ('tilt', 4),
#  ('catch', 4),
#  ('highlight', 4),
#  ('fair', 4),
#  ('reduc', 4),
#  ('p', 4),
#  ('boy', 4),
#  ('gear', 4),
#  ('strongly', 4),
#  ('benefit', 4),
#  ('thu', 4),
#  ('born', 4),
#  ('nex', 4),
#  ('christmas', 4),
#  ('pen', 4),
#  ('most', 4),
#  ('lightweight', 4),
#  ('budget', 4),
#  ('school', 4),
#  ('stud', 4),
#  ('cool', 4),
#  ('paid', 4),
#  ('up', 4),
#  ('speak', 4),
#  ('websit', 4),
#  ('noisy', 4),
#  ('cryst', 4),
#  ('layout', 4),
#  ('neck', 4),
#  ('jack', 4),
#  ('term', 4),
#  ('supery', 4),
#  ('believ', 4),
#  ('poor', 4),
#  ('shop', 4),
#  ('flashvert', 4),
#  ('bgcolor', 4),
#  ('playervert', 4),
#  ('biggest', 3),
#  ('determin', 3),
#  ('accord', 3),
#  ('ratio', 3),
#  ('togeth', 3),
#  ('virt', 3),
#  ('latest', 3),
#  ('spot', 3),
#  ('sensit', 3),
#  ('soph', 3),
#  ('sway', 3),
#  ('weath', 3),
#  ('word', 3),
#  ('scor', 3),
#  ('dark', 3),
#  ('corn', 3),
#  ('ebook', 3),
#  ('prov', 3),
#  ('composit', 3),
#  ('respect', 3),
#  ('accid', 3),
#  ('autofocus', 3),
#  ('synt', 3),
#  ('inspir', 3),
#  ('room', 3),
#  ('watch', 3),
#  ('tier', 3),
#  ('park', 3),
#  ('immedy', 3),
#  ('smugmug', 3),
#  ('heart', 3),
#  ('cont', 3),
#  ('eat', 3),
#  ('rar', 3),
#  ('juic', 3),
#  ('pop', 3),
#  ('nam', 3),
#  ('pocket', 3),
#  ('onto', 3),
#  ('ground', 3),
#  ('okay', 3),
#  ('appear', 3),
#  ('hour', 3),
#  ('baby', 3),
#  ('meant', 3),
#  ('blah', 3),
#  ('fiv', 3),
#  ('hassl', 3),
#  ('suppos', 3),
#  ('red', 3),
#  ('miss', 3),
#  ('firmw', 3),
#  ('drop', 3),
#  ('tough', 3),
#  ('hundr', 3),
#  ('l', 3),
#  ('ide', 3),
#  ('jpg', 3),
#  ('gb', 3),
#  ('hap', 3),
#  ('sampl', 3),
#  ('aspir', 3),
#  ('deep', 3),
#  ('list', 3),
#  ('lay', 3),
#  ('setup', 3),
#  ('twist', 3),
#  ('effort', 3),
#  ('frust', 3),
#  ('struggle', 3),
#  ('heard', 3),
#  ('plenty', 3),
#  ('depend', 3),
#  ('wal', 3),
#  ('wind', 3),
#  ('hdmi', 3),
#  ('plast', 3),
#  ('elimin', 3),
#  ('support', 3),
#  ('incred', 3),
#  ('newby', 3),
#  ('competit', 3),
#  ('behind', 3),
#  ('past', 3),
#  ('certain', 3),
#  ('panason', 3),
#  ('cut', 3),
#  ('half', 3),
#  ('apprecy', 3),
#  ('answ', 3),
#  ('speedlight', 3),
#  ('sor', 3),
#  ('hat', 3),
#  ('spent', 3),
#  ('kept', 3),
#  ('flo', 3),
#  ('tempt', 3),
#  ('toy', 3),
#  ('obvy', 3),
#  ('sigm', 3),
#  ('reflect', 3),
#  ('sect', 3),
#  ('mir', 3),
#  ('preset', 3),
#  ('sup', 3),
#  ('across', 3),
#  ('enthusiast', 3),
#  ('knowledg', 3),
#  ('gain', 3),
#  ('ultim', 3),
#  ('famili', 3),
#  ('glant', 3),
#  ('among', 3),
#  ('mm', 3),
#  ('outsid', 3),
#  ('tool', 3),
#  ('both', 3),
#  ('ok', 3),
#  ('ebay', 3),
#  ('project', 3),
#  ('black', 3),
#  ('med', 3),
#  ('distort', 3),
#  ('combin', 3),
#  ('awkward', 3),
#  ('hit', 3),
#  ('oh', 3),
#  ('schedule', 3),
#  ('basketbal', 3),
#  ('expl', 3),
#  ('told', 3),
#  ('comprom', 3),
#  ('blurry', 3),
#  ('girl', 3),
#  ('xt', 3),
#  ('embed', 3),
#  ('filmmak', 3),
#  ('unfortun', 3),
#  ('post', 3),
#  ('styl', 3),
#  ('intend', 3),
#  ('enlarg', 3),
#  ('convert', 3),
#  ('machin', 3),
#  ('mac', 3),
#  ('trip', 3),
#  ('grainy', 3),
#  ('copyright', 3),
#  ('buck', 3),
#  ('w', 3),
#  ('er', 3),
#  ('regx', 3),
#  ('ffversion', 3),
#  ('pts', 3),
#  ('elph', 3),
#  ('xti', 3),
#  ('mid', 3),
#  ('break', 3),
#  ('na', 3),
#  ('shelf', 3),
#  ('drain', 3),
#  ('sent', 3),
#  ('industry', 3),
#  ('compet', 2),
#  ('cosmet', 2),
#  ('borrow', 2),
#  ('brief', 2),
#  ('area', 2),
#  ('zon', 2),
#  ('num', 2),
#  ('init', 2),
#  ('respond', 2),
#  ('avid', 2),
#  ('wildl', 2),
#  ('polycarbon', 2),
#  ('seal', 2),
#  ('dai', 2),
#  ('dur', 2),
#  ('unlik', 2),
#  ('remov', 2),
#  ('sufficy', 2),
#  ('incorp', 2),
#  ('output', 2),
#  ('unus', 2),
#  ('avoid', 2),
#  ('pentapr', 2),
#  ('blaz', 2),
#  ('cf', 2),
#  ('are', 2),
#  ('smoo', 2),
#  ('cord', 2),
#  ('command', 2),
#  ('plung', 2),
#  ('firm', 2),
#  ('pet', 2),
#  ('horr', 2),
#  ('ridic', 2),
#  ('tip', 2),
#  ('endless', 2),
#  ('wow', 2),
#  ('whenev', 2),
#  ('tag', 2),
#  ('warn', 2),
#  ('story', 2),
#  ('par', 2),
#  ('precy', 2),
#  ('yeah', 2),
#  ('brain', 2),
#  ('caught', 2),
#  ('al', 2),
#  ('morn', 2),
#  ('bunch', 2),
#  ('recharg', 2),
#  ('smudg', 2),
#  ('foray', 2),
#  ('stand', 2),
#  ('surpass', 2),
#  ('connect', 2),
#  ('attract', 2),
#  ('maint', 2),
#  ...]

# %%
freq2.plot(30)

# %% [markdown]
# 3.WordNet Lemmatizer

# %%
#Steps are the same with the previous two stemmers 
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()
stem3 = [wnl.lemmatize(w) for w in words]
stem3 = [w for w in stem3]
freq3 = FreqDist(stem3)
sorted_freq3 = sorted(freq3.items(),key = lambda k: k[1], reverse = True)

# %%
sorted_freq3
# Out:
# [('camera', 647),
#  ('video', 246),
#  ('canon', 212),
#  ('lens', 191),
#  ('picture', 186),
#  ('great', 154),
#  ('use', 133),
#  ('quality', 126),
#  ('take', 118),
#  ('dslr', 108),
#  ('would', 108),
#  ('like', 105),
#  ('good', 104),
#  ('get', 103),
#  ('one', 101),
#  ('image', 94),
#  ('feature', 87),
#  ('mode', 86),
#  ('battery', 84),
#  ('want', 81),
#  ('screen', 80),
#  ('shoot', 79),
#  ('shooting', 78),
#  ('shot', 78),
#  ('setting', 76),
#  ('also', 76),
#  ('photo', 71),
#  ('time', 70),
#  ('love', 68),
#  ('really', 67),
#  ('still', 66),
#  ('better', 66),
#  ('new', 65),
#  ('first', 63),
#  ('easy', 59),
#  ('need', 58),
#  ('thing', 58),
#  ('well', 58),
#  ('even', 56),
#  ('flash', 55),
#  ('manual', 54),
#  ('point', 53),
#  ('card', 53),
#  ('hd', 51),
#  ('kit', 51),
#  ('much', 51),
#  ('lcd', 50),
#  ('used', 49),
#  ('recommend', 48),
#  ('go', 47),
#  ('auto', 46),
#  ('work', 46),
#  ('price', 46),
#  ('eos', 46),
#  ('review', 46),
#  ('photography', 46),
#  ('bought', 46),
#  ('photographer', 45),
#  ('rebel', 44),
#  ('movie', 44),
#  ('using', 44),
#  ('best', 44),
#  ('lot', 43),
#  ('make', 42),
#  ('control', 42),
#  ('digital', 42),
#  ('got', 42),
#  ('say', 42),
#  ('far', 41),
#  ('function', 41),
#  ('focus', 40),
#  ('low', 39),
#  ('nice', 39),
#  ('taking', 39),
#  ('see', 38),
#  ('nikon', 38),
#  ('high', 37),
#  ('feel', 37),
#  ('right', 37),
#  ('look', 36),
#  ('iso', 35),
#  ('slr', 35),
#  ('give', 35),
#  ('little', 35),
#  ('back', 35),
#  ('buy', 34),
#  ('button', 34),
#  ('come', 34),
#  ('amazing', 34),
#  ('amazon', 34),
#  ('many', 33),
#  ('professional', 33),
#  ('without', 33),
#  ('could', 33),
#  ('however', 32),
#  ('light', 32),
#  ('since', 31),
#  ('life', 31),
#  ('going', 31),
#  ('recording', 31),
#  ('sensor', 30),
#  ('menu', 30),
#  ('getting', 30),
#  ('money', 29),
#  ('view', 29),
#  ('full', 29),
#  ('zoom', 29),
#  ('day', 29),
#  ('around', 29),
#  ('level', 28),
#  ('change', 28),
#  ('http', 28),
#  ('different', 27),
#  ('enough', 27),
#  ('pro', 27),
#  ('learning', 27),
#  ('var', 27),
#  ('body', 26),
#  ('year', 26),
#  ('know', 26),
#  ('purchase', 26),
#  ('may', 25),
#  ('able', 25),
#  ('clear', 25),
#  ('month', 25),
#  ('never', 25),
#  ('every', 24),
#  ('big', 24),
#  ('learn', 24),
#  ('capture', 24),
#  ('range', 24),
#  ('awesome', 24),
#  ('came', 24),
#  ('definitely', 24),
#  ('system', 23),
#  ('frame', 23),
#  ('autofocus', 23),
#  ('external', 23),
#  ('find', 23),
#  ('something', 23),
#  ('sure', 23),
#  ('wanted', 22),
#  ('excellent', 22),
#  ('ever', 22),
#  ('took', 22),
#  ('went', 22),
#  ('model', 22),
#  ('taken', 22),
#  ('ca', 22),
#  ('difference', 21),
#  ('two', 21),
#  ('deal', 21),
#  ('user', 21),
#  ('set', 21),
#  ('option', 21),
#  ('speed', 21),
#  ('hand', 21),
#  ('result', 21),
#  ('beginner', 21),
#  ('always', 21),
#  ('found', 21),
#  ('compared', 21),
#  ('expensive', 20),
#  ('viewfinder', 20),
#  ('looking', 20),
#  ('pretty', 20),
#  ('fast', 20),
#  ('pic', 20),
#  ('though', 20),
#  ('perfect', 20),
#  ('product', 20),
#  ('way', 20),
#  ('capability', 19),
#  ('second', 19),
#  ('monitor', 19),
#  ('ability', 19),
#  ('subject', 19),
#  ('world', 19),
#  ('memory', 19),
#  ('grip', 19),
#  ('long', 19),
#  ('lighting', 19),
#  ('made', 19),
#  ('cmos', 19),
#  ('help', 19),
#  ('everything', 19),
#  ('le', 18),
#  ('experience', 18),
#  ('angle', 18),
#  ('start', 18),
#  ('think', 18),
#  ('anyone', 18),
#  ('already', 17),
#  ('highly', 17),
#  ('another', 17),
#  ('allows', 17),
#  ('buying', 17),
#  ('problem', 17),
#  ('research', 17),
#  ('live', 17),
#  ('said', 17),
#  ('owned', 17),
#  ('af', 16),
#  ('moment', 16),
#  ('away', 16),
#  ('color', 16),
#  ('almost', 16),
#  ('last', 16),
#  ('swivel', 16),
#  ('record', 16),
#  ('purchased', 16),
#  ('happy', 16),
#  ('power', 16),
#  ('reason', 16),
#  ('audio', 16),
#  ('sony', 16),
#  ('size', 15),
#  ('scene', 15),
#  ('probably', 15),
#  ('filter', 15),
#  ('short', 15),
#  ('plus', 15),
#  ('quickly', 15),
#  ('plan', 15),
#  ('microphone', 15),
#  ('con', 15),
#  ('dslrs', 15),
#  ('class', 15),
#  ('mic', 15),
#  ('read', 15),
#  ('needed', 15),
#  ('worth', 15),
#  ('resolution', 15),
#  ('exposure', 14),
#  ('upgrade', 14),
#  ('creative', 14),
#  ('rate', 14),
#  ('situation', 14),
#  ('quick', 14),
#  ('consider', 14),
#  ('useful', 14),
#  ('quite', 14),
#  ('issue', 14),
#  ('offer', 14),
#  ('beautiful', 14),
#  ('reading', 14),
#  ('tell', 14),
#  ('part', 14),
#  ('star', 14),
#  ('effect', 14),
#  ('decided', 14),
#  ('extra', 14),
#  ('fantastic', 14),
#  ('digic', 13),
#  ('processor', 13),
#  ('v', 13),
#  ('easily', 13),
#  ('yet', 13),
#  ('large', 13),
#  ('bright', 13),
#  ('continuous', 13),
#  ('keep', 13),
#  ('pleased', 13),
#  ('sharp', 13),
#  ('close', 13),
#  ('higher', 13),
#  ('small', 13),
#  ('especially', 13),
#  ('people', 13),
#  ('although', 13),
#  ('choice', 13),
#  ('absolutely', 13),
#  ('nsprefix', 13),
#  ('important', 12),
#  ('including', 12),
#  ('per', 12),
#  ('three', 12),
#  ('anything', 12),
#  ('pixel', 12),
#  ('top', 12),
#  ('wireless', 12),
#  ('fps', 12),
#  ('kid', 12),
#  ('busy', 12),
#  ('family', 12),
#  ('real', 12),
#  ('glad', 12),
#  ('line', 12),
#  ('seems', 12),
#  ('raw', 12),
#  ('automatic', 12),
#  ('thought', 12),
#  ('box', 12),
#  ('compact', 12),
#  ('bit', 12),
#  ('flip', 12),
#  ('else', 12),
#  ('wonderful', 12),
#  ('wife', 12),
#  ('film', 12),
#  ('remote', 11),
#  ('guide', 11),
#  ('advanced', 11),
#  ('dial', 11),
#  ('shutter', 11),
#  ('unless', 11),
#  ('sound', 11),
#  ('least', 11),
#  ('felt', 11),
#  ('person', 11),
#  ('making', 11),
#  ('friend', 11),
#  ('value', 11),
#  ('head', 11),
#  ('improved', 11),
#  ('bad', 11),
#  ('metering', 10),
#  ('might', 10),
#  ('megapixel', 10),
#  ('due', 10),
#  ('additional', 10),
#  ('access', 10),
#  ('clip', 10),
#  ('amount', 10),
#  ('instead', 10),
#  ('overall', 10),
#  ('tripod', 10),
#  ('sd', 10),
#  ('hold', 10),
#  ('course', 10),
#  ('trying', 10),
#  ('try', 10),
#  ('interface', 10),
#  ('wish', 10),
#  ('longer', 10),
#  ('free', 10),
#  ('week', 10),
#  ('fine', 10),
#  ('brand', 10),
#  ('cheap', 10),
#  ('inch', 10),
#  ('accurate', 10),
#  ('detail', 10),
#  ('fun', 10),
#  ('disappointed', 10),
#  ('complaint', 10),
#  ('rear', 9),
#  ('mp', 9),
#  ('major', 9),
#  ('type', 9),
#  ('etc', 9),
#  ('save', 9),
#  ('helpful', 9),
#  ('rating', 9),
#  ('various', 9),
#  ('similar', 9),
#  ('test', 9),
#  ('show', 9),
#  ('often', 9),
#  ('upload', 9),
#  ('home', 9),
#  ('minute', 9),
#  ('eye', 9),
#  ('left', 9),
#  ('whole', 9),
#  ('learned', 9),
#  ('amateur', 9),
#  ('several', 9),
#  ('noise', 9),
#  ('huge', 9),
#  ('let', 9),
#  ('working', 9),
#  ('fit', 9),
#  ('put', 9),
#  ('easier', 9),
#  ('end', 9),
#  ('aperture', 9),
#  ('spend', 9),
#  ('fact', 9),
#  ('accessory', 9),
#  ('field', 9),
#  ('ago', 9),
#  ('faster', 9),
#  ('son', 9),
#  ('bottom', 9),
#  ('understand', 9),
#  ('h', 9),
#  ('addition', 8),
#  ('share', 8),
#  ('nearly', 8),
#  ('larger', 8),
#  ('portrait', 8),
#  ('snapshot', 8),
#  ('construction', 8),
#  ('built', 8),
#  ('white', 8),
#  ('operation', 8),
#  ('turn', 8),
#  ('camcorder', 8),
#  ('rather', 8),
#  ('manually', 8),
#  ('ease', 8),
#  ('basic', 8),
#  ('knew', 8),
#  ('care', 8),
#  ('seen', 8),
#  ('sometimes', 8),
#  ('leave', 8),
#  ('previous', 8),
#  ('standard', 8),
#  ('uploading', 8),
#  ('update', 8),
#  ('stuff', 8),
#  ('add', 8),
#  ('sdhc', 8),
#  ('series', 8),
#  ('operate', 8),
#  ('event', 8),
#  ('version', 8),
#  ('experiment', 8),
#  ('software', 8),
#  ('switch', 8),
#  ('available', 8),
#  ('amazed', 8),
#  ('job', 8),
#  ('slow', 8),
#  ('stop', 8),
#  ('chose', 8),
#  ('thanks', 8),
#  ('mark', 8),
#  ('cheaper', 8),
#  ('opinion', 8),
#  ('wait', 8),
#  ('im', 8),
#  ('tamron', 8),
#  ('performance', 7),
#  ('difficult', 7),
#  ('choose', 7),
#  ('produce', 7),
#  ('automatically', 7),
#  ('lighter', 7),
#  ('balance', 7),
#  ('macro', 7),
#  ('wo', 7),
#  ('actually', 7),
#  ('extremely', 7),
#  ('smaller', 7),
#  ('weight', 7),
#  ('note', 7),
#  ('party', 7),
#  ('serious', 7),
#  ('picked', 7),
#  ('simple', 7),
#  ('next', 7),
#  ('true', 7),
#  ('play', 7),
#  ('blown', 7),
#  ('improve', 7),
#  ('entry', 7),
#  ('u', 7),
#  ('common', 7),
#  ('hard', 7),
#  ('gave', 7),
#  ('return', 7),
#  ('adjustment', 7),
#  ('investment', 7),
#  ('truly', 7),
#  ('nicely', 7),
#  ('photoshop', 7),
#  ('necessary', 7),
#  ('youtube', 7),
#  ('side', 7),
#  ('purchasing', 7),
#  ('old', 7),
#  ('online', 7),
#  ('ii', 7),
#  ('must', 7),
#  ('cost', 7),
#  ('mine', 7),
#  ('wide', 7),
#  ('impressed', 7),
#  ('pick', 7),
#  ('purpose', 7),
#  ('x', 7),
#  ('exceptional', 7),
#  ('maximum', 7),
#  ('sorry', 7),
#  ('soon', 7),
#  ('ended', 7),
#  ('crop', 7),
#  ('wedding', 7),
#  ('yes', 7),
#  ('child', 7),
#  ('daughter', 7),
#  ('curve', 7),
#  ('couple', 6),
#  ('step', 6),
#  ('exactly', 6),
#  ('multiple', 6),
#  ('intelligent', 6),
#  ('playback', 6),
#  ('mean', 6),
#  ('allow', 6),
#  ('object', 6),
#  ('sport', 6),
#  ('someone', 6),
#  ('relatively', 6),
#  ('fix', 6),
#  ('photograph', 6),
#  ('articulating', 6),
#  ('action', 6),
#  ('adjust', 6),
#  ('case', 6),
#  ('mom', 6),
#  ('gotten', 6),
#  ('invest', 6),
#  ('favorite', 6),
#  ('move', 6),
#  ('saying', 6),
#  ('footage', 6),
#  ('display', 6),
#  ('computer', 6),
#  ('within', 6),
#  ('via', 6),
#  ('ready', 6),
#  ('impressive', 6),
#  ('superb', 6),
#  ('editing', 6),
#  ('received', 6),
#  ('started', 6),
#  ('stabilization', 6),
#  ('recently', 6),
#  ('looked', 6),
#  ('glass', 6),
#  ('comfortable', 6),
#  ('granted', 6),
#  ('nothing', 6),
#  ('saw', 6),
#  ('compare', 6),
#  ('handy', 6),
#  ('general', 6),
#  ('particularly', 6),
#  ('utility', 6),
#  ('remember', 6),
#  ('example', 6),
#  ('simply', 6),
#  ('aspect', 6),
#  ('file', 6),
#  ('main', 6),
#  ('place', 6),
#  ('enjoy', 6),
#  ('recommended', 6),
#  ('night', 6),
#  ('direction', 6),
#  ('decision', 6),
#  ('frequently', 6),
#  ('p', 6),
#  ('expect', 6),
#  ('number', 6),
#  ('ef', 6),
#  ('heavy', 6),
#  ('slrs', 6),
#  ('shipping', 6),
#  ('worked', 6),
#  ('gift', 6),
#  ('tax', 6),
#  ('imaging', 6),
#  ('clarity', 6),
#  ('swflocation', 6),
#  ('movieid', 6),
#  ('older', 5),
#  ('considering', 5),
#  ('minor', 5),
#  ('powerful', 5),
#  ('center', 5),
#  ('check', 5),
#  ('tv', 5),
#  ('walk', 5),
#  ('videographers', 5),
#  ('finder', 5),
#  ('store', 5),
#  ('rest', 5),
#  ('channel', 5),
#  ('filming', 5),
#  ('dedicated', 5),
#  ('intuitive', 5),
#  ('everywhere', 5),
#  ('grow', 5),
#  ('usually', 5),
#  ('snap', 5),
#  ('amazingly', 5),
#  ('playing', 5),
#  ('open', 5),
#  ('material', 5),
#  ('normal', 5),
#  ('sort', 5),
#  ('requires', 5),
#  ('finally', 5),
#  ('experimenting', 5),
#  ('arrived', 5),
#  ('adapter', 5),
#  ('annoying', 5),
#  ('loving', 5),
#  ('honestly', 5),
#  ('item', 5),
#  ('knowing', 5),
#  ('order', 5),
#  ('called', 5),
#  ('solid', 5),
#  ('write', 5),
#  ('liked', 5),
#  ('require', 5),
#  ('others', 5),
#  ('call', 5),
#  ('question', 5),
#  ('wrong', 5),
#  ('iii', 5),
#  ('captured', 5),
#  ('prefer', 5),
#  ('cable', 5),
#  ('provides', 5),
#  ('regular', 5),
#  ('skill', 5),
#  ('experienced', 5),
#  ('owner', 5),
#  ('lower', 5),
#  ('whether', 5),
#  ('input', 5),
#  ('terminal', 5),
#  ('crisp', 5),
#  ('aware', 5),
#  ('single', 5),
#  ('included', 5),
#  ('laptop', 5),
#  ('lack', 5),
#  ('outstanding', 5),
#  ('upgrading', 5),
#  ('decide', 5),
#  ('customer', 5),
#  ('equipment', 5),
#  ('anyway', 5),
#  ('tone', 5),
#  ('sold', 5),
#  ('everyone', 5),
#  ('guess', 5),
#  ('done', 5),
#  ('hope', 5),
#  ('beat', 5),
#  ('indoor', 5),
#  ('dim', 5),
#  ('device', 5),
#  ('olympus', 5),
#  ('technology', 5),
#  ('base', 5),
#  ('market', 5),
#  ('studio', 5),
#  ('completely', 5),
#  ('information', 5),
#  ('mbps', 5),
#  ('either', 5),
#  ('thinking', 5),
#  ('loved', 5),
#  ('mind', 5),
#  ('enhanced', 5),
#  ('approximately', 5),
#  ('format', 5),
#  ('guy', 5),
#  ('swfwidth', 5),
#  ('swfheight', 5),
#  ('swfparams', 5),
#  ('flashparams', 5),
#  ('embedattributes', 5),
#  ('vacation', 5),
#  ('service', 5),
#  ('rebate', 5),
#  ('rotating', 4),
#  ('slightly', 4),
#  ('trigger', 4),
#  ('include', 4),
#  ('landscape', 4),
#  ('q', 4),
#  ('description', 4),
#  ('area', 4),
#  ('focusing', 4),
#  ('group', 4),
#  ('custom', 4),
#  ('possible', 4),
#  ('distance', 4),
#  ('strong', 4),
#  ('travel', 4),
#  ('exact', 4),
#  ('complicated', 4),
#  ('moved', 4),
#  ('thumb', 4),
#  ('program', 4),
#  ('av', 4),
#  ('direct', 4),
#  ('creation', 4),
#  ('begin', 4),
#  ('master', 4),
#  ('electronic', 4),
#  ('coverage', 4),
#  ('us', 4),
#  ('improvement', 4),
#  ('touch', 4),
#  ('game', 4),
#  ('desired', 4),
#  ('pc', 4),
#  ('plug', 4),
#  ('confusing', 4),
#  ('expert', 4),
#  ('pulling', 4),
#  ('opportunity', 4),
#  ('decent', 4),
#  ('stay', 4),
#  ('become', 4),
#  ('constantly', 4),
#  ('capturing', 4),
#  ('click', 4),
#  ('toddler', 4),
#  ('coming', 4),
#  ('seeing', 4),
#  ('compatible', 4),
#  ('husband', 4),
#  ('account', 4),
#  ('later', 4),
#  ('run', 4),
#  ('charger', 4),
#  ('challenge', 4),
#  ('bulky', 4),
#  ('worry', 4),
#  ('keeping', 4),
#  ('soft', 4),
#  ('totally', 4),
#  ('stick', 4),
#  ('indoors', 4),
#  ('bag', 4),
#  ('mega', 4),
#  ('intermediate', 4),
#  ('flower', 4),
#  ('mainly', 4),
#  ('search', 4),
#  ('fixed', 4),
#  ('currently', 4),
#  ('link', 4),
#  ('powershot', 4),
#  ('figured', 4),
#  ('maybe', 4),
#  ('future', 4),
#  ('selling', 4),
#  ('noticed', 4),
#  ('upon', 4),
#  ('strap', 4),
#  ('recommendation', 4),
#  ('prime', 4),
#  ('dollar', 4),
#  ('third', 4),
#  ('perfectly', 4),
#  ('site', 4),
#  ('lightroom', 4),
#  ('regret', 4),
#  ('process', 4),
#  ('jump', 4),
#  ('brother', 4),
#  ('xsi', 4),
#  ('lapse', 4),
#  ('talk', 4),
#  ('popular', 4),
#  ('thousand', 4),
#  ('push', 4),
#  ('suggest', 4),
#  ('face', 4),
#  ('stunning', 4),
#  ('novice', 4),
#  ('tend', 4),
#  ('generally', 4),
#  ('front', 4),
#  ('useless', 4),
#  ('reliable', 4),
#  ('info', 4),
#  ('location', 4),
#  ('match', 4),
#  ('unit', 4),
#  ('wear', 4),
#  ('affordable', 4),
#  ('interview', 4),
#  ('stereo', 4),
#  ('motion', 4),
#  ('surprisingly', 4),
#  ('length', 4),
#  ('surprise', 4),
#  ('cannon', 4),
#  ('reasonably', 4),
#  ('upgraded', 4),
#  ('forward', 4),
#  ('stock', 4),
#  ('along', 4),
#  ('bigger', 4),
#  ('catch', 4),
#  ('moving', 4),
#  ('usable', 4),
#  ('highlight', 4),
#  ('priority', 4),
#  ('boy', 4),
#  ('extreme', 4),
#  ('tested', 4),
#  ('nikons', 4),
#  ('gear', 4),
#  ('adjustable', 4),
#  ('strongly', 4),
#  ('thus', 4),
#  ('born', 4),
#  ('nex', 4),
#  ('christmas', 4),
#  ('extended', 4),
#  ('pen', 4),
#  ('mostly', 4),
#  ('starting', 4),
#  ('lightweight', 4),
#  ('performs', 4),
#  ('budget', 4),
#  ('school', 4),
#  ('student', 4),
#  ('priced', 4),
#  ('starter', 4),
#  ('cool', 4),
#  ('paid', 4),
#  ('expectation', 4),
#  ('website', 4),
#  ('crystal', 4),
#  ('seem', 4),
#  ('gripe', 4),
#  ('viewing', 4),
#  ('layout', 4),
#  ('neck', 4),
#  ('jack', 4),
#  ('saved', 4),
#  ('term', 4),
#  ('superior', 4),
#  ('basically', 4),
#  ('returning', 4),
#  ('believe', 4),
#  ('added', 4),
#  ('expected', 4),
#  ('flashversion', 4),
#  ('bgcolor', 4),
#  ('playerversion', 4),
#  ('skin', 4),
#  ('shelf', 4),
#  ('sitting', 4),
#  ('consumer', 3),
#  ('closer', 3),
#  ('firing', 3),
#  ('processing', 3),
#  ('create', 3),
#  ('heavier', 3),
#  ('biggest', 3),
#  ('accordingly', 3),
#  ('costly', 3),
#  ('ratio', 3),
#  ('press', 3),
#  ('together', 3),
#  ('virtually', 3),
#  ('capable', 3),
#  ('latest', 3),
#  ('enable', 3),
#  ('spot', 3),
#  ('sophisticated', 3),
#  ('customize', 3),
#  ('figure', 3),
#  ('weather', 3),
#  ('word', 3),
#  ('score', 3),
#  ('placed', 3),
#  ('matter', 3),
#  ('dark', 3),
#  ('corner', 3),
#  ('tweaking', 3),
#  ('composition', 3),
#  ('visible', 3),
#  ('actual', 3),
#  ('designed', 3),
#  ('kind', 3),
#  ('typically', 3),
#  ('autofocusing', 3),
#  ('sync', 3),
#  ('inspired', 3),
#  ('room', 3),
#  ('friendly', 3),
#  ('delay', 3),
#  ('meaning', 3),
#  ('tier', 3),
#  ('park', 3),
#  ('immediately', 3),
#  ('smugmug', 3),
#  ('heart', 3),
#  ('content', 3),
#  ('charge', 3),
#  ('rarely', 3),
#  ('juice', 3),
#  ('pocket', 3),
#  ('solution', 3),
#  ('onto', 3),
#  ('ground', 3),
#  ('okay', 3),
#  ('hour', 3),
#  ('finish', 3),
#  ('facing', 3),
#  ('outdoors', 3),
#  ('required', 3),
#  ('minimum', 3),
#  ('baby', 3),
#  ('following', 3),
#  ('meant', 3),
#  ('blah', 3),
#  ('surprised', 3),
#  ('natural', 3),
#  ('selection', 3),
#  ('five', 3),
#  ('hassle', 3),
#  ('practice', 3),
#  ('supposed', 3),
#  ('red', 3),
#  ('interesting', 3),
#  ('comment', 3),
#  ('firmware', 3),
#  ('opening', 3),
#  ('realized', 3),
#  ('pay', 3),
#  ('hundred', 3),
#  ('l', 3),
#  ('seriously', 3),
#  ('data', 3),
#  ('idea', 3),
#  ('jpg', 3),
#  ('gb', 3),
#  ('speedlite', 3),
#  ('enjoying', 3),
#  ('happens', 3),
#  ('sample', 3),
#  ('select', 3),
#  ('ship', 3),
#  ('suitable', 3),
#  ('desire', 3),
#  ('considered', 3),
#  ('deep', 3),
#  ('separate', 3),
#  ('setup', 3),
#  ('four', 3),
#  ('effort', 3),
#  ('realize', 3),
#  ('convinced', 3),
#  ('reviewer', 3),
#  ('spec', 3),
#  ('variety', 3),
#  ('struggle', 3),
#  ('heard', 3),
#  ('plenty', 3),
#  ('includes', 3),
#  ('allowing', 3),
#  ('mentioned', 3),
#  ('earlier', 3),
#  ('limited', 3),
#  ('port', 3),
#  ('wall', 3),
#  ('effective', 3),
#  ('production', 3),
#  ('mics', 3),
#  ('directly', 3),
#  ('hdmi', 3),
#  ('plastic', 3),
#  ('magic', 3),
#  ('walking', 3),
#  ('support', 3),
#  ('package', 3),
#  ('searching', 3),
#  ('newbie', 3),
#  ('hesitation', 3),
#  ('losing', 3),
#  ('behind', 3),
#  ('past', 3),
#  ('excels', 3),
#  ('zooming', 3),
#  ('panasonic', 3),
#  ('cut', 3),
#  ('half', 3),
#  ('appreciate', 3),
#  ('speedlight', 3),
#  ('carry', 3),
#  ('detailed', 3),
#  ('happier', 3),
#  ('spent', 3),
#  ('kept', 3),
#  ('toy', 3),
#  ('sigma', 3),
#  ('researching', 3),
#  ('mirror', 3),
#  ('super', 3),
#  ('cam', 3),
#  ('across', 3),
#  ...]

# %%
freq3.plot(30)

# %%
#write result into .txt file
with open('stemming_output.txt','w') as f:
    for word, frequency in sorted_freq1: #here you can change to sorted_freq2 or 3 
        f.write(str(word)+'\t'+str(frequency)+'\n')

# %% [markdown]
# ### Part of Speech Tags

# %% [markdown]
# - NN: Noun, singular or mass
# - NNP: Proper noun, singular
# - NNS: Noun, plural
# - NNPS: Proper noun, plural

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/ricardolu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
POS_tags = nltk.pos_tag(tokens) #use unprocessed 'tokens', not 'words'

#Generate a list of POS tags
POS_tag_list = [(word,tag) for (word,tag) in POS_tags if tag.startswith('N')]

# %%
#Generate a frequency distribution of all the POS tags
tag_freq = nltk.FreqDist(POS_tag_list)
#Sort the result 
sorted_tag_freq = sorted(tag_freq.items(), key = lambda k:k[1], reverse = True)

# %%
sorted_tag_freq
# Out:
# [(('camera', 'NN'), 540),
#  (('T3i', 'NNP'), 225),
#  (('video', 'NN'), 197),
#  (('Canon', 'NNP'), 191),
#  (('pictures', 'NNS'), 133),
#  (('quality', 'NN'), 115),
#  (('DSLR', 'NNP'), 84),
#  (('cameras', 'NNS'), 75),
#  (('screen', 'NN'), 69),
#  (('mode', 'NN'), 65),
#  (('time', 'NN'), 60),
#  (('battery', 'NN'), 60),
#  (('lens', 'NNS'), 56),
#  (('T2i', 'NNP'), 55),
#  (('HD', 'NNP'), 51),
#  (('shots', 'NNS'), 50),
#  (('point', 'NN'), 46),
#  (('features', 'NNS'), 45),
#  (('settings', 'NNS'), 45),
#  (('EOS', 'NNP'), 45),
#  (('photography', 'NN'), 45),
#  (('LCD', 'NNP'), 44),
#  (('kit', 'NN'), 43),
#  (('photos', 'NNS'), 43),
#  (('lenses', 'NNS'), 42),
#  (('price', 'NN'), 42),
#  (('flash', 'NN'), 41),
#  (('images', 'NNS'), 41),
#  (('card', 'NN'), 38),
#  (('picture', 'NN'), 38),
#  (('image', 'NN'), 37),
#  (('Rebel', 'NNP'), 36),
#  (('shoot', 'NN'), 36),
#  (('lot', 'NN'), 36),
#  (('feature', 'NN'), 34),
#  (('SLR', 'NNP'), 33),
#  (('Nikon', 'NNP'), 33),
#  (('thing', 'NN'), 32),
#  (('ISO', 'NNP'), 31),
#  (('focus', 'NN'), 30),
#  (('auto', 'NN'), 30),
#  (('money', 'NN'), 29),
#  (('sensor', 'NN'), 28),
#  (('photographer', 'NN'), 28),
#  (('http', 'NN'), 28),
#  (('Amazon', 'NNP'), 28),
#  (('life', 'NN'), 27),
#  (('things', 'NNS'), 26),
#  (('review', 'NN'), 26),
#  (('i', 'NN'), 25),
#  (('movie', 'NN'), 24),
#  (('body', 'NN'), 23),
#  (('function', 'NN'), 23),
#  (('something', 'NN'), 23),
#  (('controls', 'NNS'), 22),
#  (('range', 'NN'), 22),
#  (('system', 'NN'), 21),
#  (('lens', 'NN'), 21),
#  (('level', 'NN'), 20),
#  (('use', 'NN'), 20),
#  (('years', 'NNS'), 20),
#  (('light', 'NN'), 20),
#  (('way', 'NN'), 20),
#  (('setting', 'NN'), 20),
#  (('CMOS', 'NNP'), 19),
#  (('autofocus', 'NN'), 18),
#  (('button', 'NN'), 18),
#  (('deal', 'NN'), 18),
#  (('view', 'NN'), 18),
#  (('zoom', 'NN'), 18),
#  (('Camera', 'NNP'), 18),
#  (('IS', 'NNP'), 18),
#  (('monitor', 'NN'), 17),
#  (('ability', 'NN'), 17),
#  (('viewfinder', 'NN'), 17),
#  (('speed', 'NN'), 17),
#  (('pics', 'NNS'), 17),
#  (('anyone', 'NN'), 17),
#  (('reviews', 'NNS'), 17),
#  (('AF', 'NNP'), 16),
#  (('options', 'NNS'), 16),
#  (('shooting', 'NN'), 16),
#  (('grip', 'NN'), 16),
#  (('months', 'NNS'), 16),
#  (('batteries', 'NNS'), 16),
#  (('world', 'NN'), 16),
#  (('results', 'NNS'), 16),
#  (('canon', 'NN'), 16),
#  (('Sony', 'NNP'), 16),
#  (('difference', 'NN'), 15),
#  (('modes', 'NNS'), 15),
#  (('memory', 'NN'), 15),
#  (('day', 'NN'), 15),
#  (('experience', 'NN'), 15),
#  (('menu', 'NN'), 15),
#  (('research', 'NN'), 15),
#  (('resolution', 'NN'), 15),
#  (('Auto', 'NNP'), 14),
#  (('photos', 'NN'), 14),
#  (('swivel', 'NN'), 14),
#  (('Digital', 'NNP'), 14),
#  (('DSLRs', 'NNP'), 14),
#  (('power', 'NN'), 14),
#  (('days', 'NNS'), 14),
#  (('D5100', 'NNP'), 14),
#  (('product', 'NN'), 14),
#  (('capabilities', 'NNS'), 13),
#  (('size', 'NN'), 13),
#  (('buttons', 'NNS'), 13),
#  (('microphone', 'NN'), 13),
#  (('part', 'NN'), 13),
#  (('lighting', 'NN'), 13),
#  (('Lens', 'NNP'), 13),
#  (('cards', 'NNS'), 13),
#  (('people', 'NNS'), 13),
#  (('everything', 'NN'), 13),
#  (('movies', 'NNS'), 13),
#  (('rate', 'NN'), 12),
#  (('Video', 'NNP'), 12),
#  (('Image', 'NNP'), 12),
#  (('functions', 'NNS'), 12),
#  (('%', 'NN'), 12),
#  (('feel', 'NN'), 12),
#  (('kids', 'NNS'), 12),
#  (('user', 'NN'), 12),
#  (('photographers', 'NNS'), 12),
#  (('purchase', 'NN'), 12),
#  (('beginner', 'NN'), 12),
#  (('choice', 'NN'), 12),
#  (('=', 'NNP'), 12),
#  (('exposure', 'NN'), 11),
#  (('frames', 'NNS'), 11),
#  (('anything', 'NN'), 11),
#  (('dSLR', 'NN'), 11),
#  (('family', 'NN'), 11),
#  (('t3i', 'NN'), 11),
#  (('model', 'NN'), 11),
#  (('shot', 'NN'), 11),
#  (('problem', 'NN'), 11),
#  (('mic', 'NN'), 11),
#  (('box', 'NN'), 11),
#  (('models', 'NNS'), 11),
#  (('access', 'NN'), 10),
#  (('subject', 'NN'), 10),
#  (('amount', 'NN'), 10),
#  (('hand', 'NN'), 10),
#  (('course', 'NN'), 10),
#  (('look', 'NN'), 10),
#  (('interface', 'NN'), 10),
#  (('line', 'NN'), 10),
#  (('one', 'NN'), 10),
#  (('person', 'NN'), 10),
#  (('RAW', 'NNP'), 10),
#  (('hands', 'NNS'), 10),
#  (('videos', 'NNS'), 10),
#  (('audio', 'NN'), 10),
#  (('value', 'NN'), 10),
#  (('reason', 'NN'), 10),
#  (('head', 'NN'), 10),
#  (('wife', 'NN'), 10),
#  (('MP', 'NNP'), 9),
#  (('second', 'NN'), 9),
#  (('situations', 'NNS'), 9),
#  (('control', 'NN'), 9),
#  (('SD', 'NNP'), 9),
#  (('shutter', 'NN'), 9),
#  (('beginners', 'NNS'), 9),
#  (('moments', 'NNS'), 9),
#  (('color', 'NN'), 9),
#  (('home', 'NN'), 9),
#  (('noise', 'NN'), 9),
#  (('EF-S', 'NNP'), 9),
#  (('class', 'NN'), 9),
#  (('issue', 'NN'), 9),
#  (('times', 'NNS'), 9),
#  (('fact', 'NN'), 9),
#  (('field', 'NN'), 9),
#  (('DIGIC', 'NNP'), 9),
#  (('son', 'NN'), 9),
#  (('bit', 'NN'), 9),
#  (('film', 'NN'), 9),
#  (('recording', 'NN'), 9),
#  (('document.getElementById', 'NN'), 9),
#  (('processor', 'NN'), 8),
#  (('clips', 'NNS'), 8),
#  (('dial', 'NN'), 8),
#  (('tripod', 'NN'), 8),
#  (('fps', 'NN'), 8),
#  (('camcorder', 'NN'), 8),
#  (('photo', 'NN'), 8),
#  (('point-and-shoot', 'NN'), 8),
#  (('minutes', 'NNS'), 8),
#  (('stuff', 'NN'), 8),
#  (('f/3.5-5.6', 'NN'), 8),
#  (('SDHC', 'NNP'), 8),
#  (('brand', 'NN'), 8),
#  (('angles', 'NNS'), 8),
#  (('software', 'NN'), 8),
#  (('flip', 'NN'), 8),
#  (('job', 'NN'), 8),
#  (('month', 'NN'), 8),
#  (('addition', 'NN'), 7),
#  (('performance', 'NN'), 7),
#  (('type', 'NN'), 7),
#  (('points', 'NNS'), 7),
#  (('subjects', 'NNS'), 7),
#  (('changes', 'NNS'), 7),
#  (('moment', 'NN'), 7),
#  (('investment', 'NN'), 7),
#  (('stars', 'NNS'), 7),
#  (('shoots', 'NNS'), 7),
#  (('need', 'NN'), 7),
#  (('side', 'NN'), 7),
#  (('series', 'NN'), 7),
#  (('friend', 'NN'), 7),
#  (('version', 'NN'), 7),
#  (('II', 'NNP'), 7),
#  (('end', 'NN'), 7),
#  (('right', 'NN'), 7),
#  (('Best', 'NNP'), 7),
#  (('accessories', 'NNS'), 7),
#  (('inches', 'NNS'), 7),
#  (('View', 'NNP'), 7),
#  (('fun', 'NN'), 7),
#  (('auto-focus', 'NN'), 7),
#  (('opinion', 'NN'), 7),
#  (('Great', 'NNP'), 7),
#  (('daughter', 'NN'), 7),
#  (('curve', 'NN'), 7),
#  (('love', 'NN'), 7),
#  (('h', 'NN'), 7),
#  (('+', 'NN'), 7),
#  ((']', 'NNP'), 7),
#  (('differences', 'NNS'), 6),
#  (('share', 'NN'), 6),
#  (('flashes', 'NNS'), 6),
#  (('rating', 'NN'), 6),
#  (('Guide', 'NNP'), 6),
#  (('sports', 'NNS'), 6),
#  (('someone', 'NN'), 6),
#  (('construction', 'NN'), 6),
#  (('frame', 'NN'), 6),
#  (('pixel', 'NN'), 6),
#  (('Menu', 'NNP'), 6),
#  (('menus', 'NN'), 6),
#  (('balance', 'NN'), 6),
#  (('levels', 'NNS'), 6),
#  (('angle', 'NN'), 6),
#  (('action', 'NN'), 6),
#  (('weight', 'NN'), 6),
#  (('Full', 'NNP'), 6),
#  (('capability', 'NN'), 6),
#  (('sound', 'NN'), 6),
#  (('footage', 'NN'), 6),
#  (('TO', 'NNP'), 6),
#  (('entry', 'NN'), 6),
#  (('computer', 'NN'), 6),
#  (('Photoshop', 'NNP'), 6),
#  (('weeks', 'NNS'), 6),
#  (('stabilization', 'NN'), 6),
#  (('products', 'NNS'), 6),
#  (('year', 'NN'), 6),
#  (('mine', 'NN'), 6),
#  (('Live', 'NNP'), 6),
#  (('effects', 'NNS'), 6),
#  (('example', 'NN'), 6),
#  (('reasons', 'NNS'), 6),
#  (('record', 'NN'), 6),
#  (('detail', 'NN'), 6),
#  (('upgrade', 'NN'), 6),
#  (('night', 'NN'), 6),
#  (('Buy', 'NNP'), 6),
#  (('Pros', 'NNS'), 6),
#  (('THE', 'NNP'), 6),
#  (('number', 'NN'), 6),
#  (('Tamron', 'NNP'), 6),
#  (('EF', 'NNP'), 6),
#  (('SLRs', 'NNP'), 6),
#  (('back', 'NN'), 6),
#  (('dslr', 'NN'), 6),
#  (('complaint', 'NN'), 6),
#  (('gift', 'NN'), 6),
#  (('Camera', 'NN'), 6),
#  (('amateur', 'NN'), 6),
#  (('Megapixel', 'NNP'), 6),
#  (('Movie', 'NNP'), 6),
#  (('New', 'NNP'), 6),
#  (('clarity', 'NN'), 6),
#  (('swfLocation', 'NN'), 6),
#  (('v', 'NN'), 6),
#  (('Scene', 'NNP'), 5),
#  (('scene', 'NN'), 5),
#  (('playback', 'NN'), 5),
#  (('Snapshot', 'NNP'), 5),
#  (('metering', 'NN'), 5),
#  (('situation', 'NN'), 5),
#  (('center', 'NN'), 5),
#  (('needs', 'NNS'), 5),
#  (('change', 'NN'), 5),
#  (('videographers', 'NNS'), 5),
#  (('case', 'NN'), 5),
#  (('Flash', 'NNP'), 5),
#  (('mom', 'NN'), 5),
#  (('*', 'NN'), 5),
#  (('step', 'NN'), 5),
#  (('wireless', 'NN'), 5),
#  (('cons', 'NNS'), 5),
#  (('ease', 'NN'), 5),
#  (('filters', 'NNS'), 5),
#  (('effect', 'NN'), 5),
#  (('Zoom', 'NNP'), 5),
#  (('Just', 'NNP'), 5),
#  (('order', 'NN'), 5),
#  (('videos', 'NN'), 5),
#  (('party', 'NN'), 5),
#  (('professionals', 'NNS'), 5),
#  (('glass', 'NN'), 5),
#  (('online', 'NN'), 5),
#  (('others', 'NNS'), 5),
#  (('questions', 'NNS'), 5),
#  (('aperture', 'NN'), 5),
#  (('utility', 'NN'), 5),
#  (('feels', 'NNS'), 5),
#  (('T3i', 'NN'), 5),
#  (('nothing', 'NN'), 5),
#  (('terminal', 'NN'), 5),
#  (('equipment', 'NN'), 5),
#  (('thanks', 'NNS'), 5),
#  (('decision', 'NN'), 5),
#  (('Cons', 'NNS'), 5),
#  (('everyone', 'NN'), 5),
#  (('wedding', 'NN'), 5),
#  (('learning', 'NN'), 5),
#  (('Olympus', 'NNP'), 5),
#  (('colors', 'NNS'), 5),
#  (('work', 'NN'), 5),
#  (('market', 'NN'), 5),
#  (('[', 'NN'), 5),
#  (('MBps', 'NNP'), 5),
#  (('mind', 'NN'), 5),
#  ((']', 'NN'), 5),
#  (('guy', 'NN'), 5),
#  (('<', 'NN'), 5),
#  (('fp_resizePlayerSpace', 'NN'), 5),
#  (('cv_mo12FP77FNBABNRso.setAttribute', 'NN'), 5),
#  (('movieID', 'NN'), 5),
#  (('service', 'NN'), 5),
#  (('lcd', 'NN'), 5),
#  (('Digic', 'NNP'), 4),
#  (('Intelligent', 'NNP'), 4),
#  (('Mode', 'NNP'), 4),
#  (('landscape', 'NN'), 4),
#  (('Filters', 'NNS'), 4),
#  (('Q', 'NNP'), 4),
#  (('group', 'NN'), 4),
#  (('users', 'NNS'), 4),
#  (('Quick', 'NNP'), 4),
#  (('Control', 'NNP'), 4),
#  (('operation', 'NN'), 4),
#  (('Photographer', 'NNP'), 4),
#  (('Operation', 'NNP'), 4),
#  (('Creation', 'NNP'), 4),
#  (('/', 'NNP'), 4),
#  (('finder', 'NN'), 4),
#  (('coverage', 'NN'), 4),
#  (('issues', 'NNS'), 4),
#  (('A', 'NNP'), 4),
#  (('channel', 'NN'), 4),
#  (('touch', 'NN'), 4),
#  (('PC', 'NN'), 4),
#  (('expert', 'NN'), 4),
#  (('opportunity', 'NN'), 4),
#  (('care', 'NN'), 4),
#  (('PROS', 'NNS'), 4),
#  (('VERY', 'NNP'), 4),
#  (('toddler', 'NN'), 4),
#  (('VIDEO', 'NNP'), 4),
#  (('BIG', 'NNP'), 4),
#  (('husband', 'NN'), 4),
#  (('account', 'NN'), 4),
#  (('charger', 'NN'), 4),
#  (('eye', 'NN'), 4),
#  (('adjustment', 'NN'), 4),
#  (('indoors', 'NNS'), 4),
#  (('bag', 'NN'), 4),
#  (('Screen', 'NNP'), 4),
#  (('problems', 'NNS'), 4),
#  (('guide', 'NN'), 4),
#  (('D3100', 'NNP'), 4),
#  (('flowers', 'NNS'), 4),
#  (('start', 'NN'), 4),
#  (('search', 'NN'), 4),
#  (('test', 'NN'), 4),
#  (('ones', 'NNS'), 4),
#  (('remote', 'NN'), 4),
#  (('amazon', 'NN'), 4),
#  (('events', 'NNS'), 4),
#  (('strap', 'NN'), 4),
#  (('display', 'NN'), 4),
#  (('friends', 'NNS'), 4),
#  (('Lightroom', 'NNP'), 4),
#  (('event', 'NN'), 4),
#  (('III', 'NNP'), 4),
#  (('plan', 'NN'), 4),
#  (('YouTube', 'NNP'), 4),
#  (('FULL', 'NNP'), 4),
#  (('cable', 'NN'), 4),
#  (('pixels', 'NNS'), 4),
#  (('novice', 'NN'), 4),
#  (('details', 'NNS'), 4),
#  (('seconds', 'NNS'), 4),
#  (('location', 'NN'), 4),
#  (('unit', 'NN'), 4),
#  (('filter', 'NN'), 4),
#  (('purposes', 'NNS'), 4),
#  (('input', 'NN'), 4),
#  (('/', 'NN'), 4),
#  (('bottom', 'NN'), 4),
#  (('x', 'NN'), 4),
#  (('motion', 'NN'), 4),
#  (('aspect', 'NN'), 4),
#  (('file', 'NN'), 4),
#  (('Cannon', 'NNP'), 4),
#  (('Pro', 'NNP'), 4),
#  (('place', 'NN'), 4),
#  (('stock', 'NN'), 4),
#  (('customer', 'NN'), 4),
#  (('star', 'NN'), 4),
#  (('option', 'NN'), 4),
#  (('eyes', 'NNS'), 4),
#  (('week', 'NN'), 4),
#  (('rest', 'NN'), 4),
#  (('return', 'NN'), 4),
#  (('IT', 'NNP'), 4),
#  (('mark', 'NN'), 4),
#  (('materials', 'NNS'), 4),
#  (('portraits', 'NNS'), 4),
#  (('im', 'NN'), 4),
#  (('shipping', 'NN'), 4),
#  (('budget', 'NN'), 4),
#  (('lots', 'NNS'), 4),
#  (('studio', 'NN'), 4),
#  (('school', 'NN'), 4),
#  (('student', 'NN'), 4),
#  (('complaints', 'NNS'), 4),
#  (('First', 'NNP'), 4),
#  (('tax', 'NN'), 4),
#  (('QUALITY', 'NNP'), 4),
#  (('expectations', 'NNS'), 4),
#  (('website', 'NN'), 4),
#  (('gripe', 'NN'), 4),
#  (('APS-C', 'NNP'), 4),
#  (('format', 'NN'), 4),
#  (('neck', 'NN'), 4),
#  (('jack', 'NN'), 4),
#  (('Everything', 'NN'), 4),
#  (('children', 'NNS'), 4),
#  (('[', 'NNP'), 4),
#  (('flashVersion', 'NN'), 4),
#  (('bgColor', 'NN'), 4),
#  (('embedAttributes', 'NNS'), 4),
#  (('playerVersion', 'NN'), 4),
#  (('skin', 'NN'), 4),
#  (('//www.amazon.com/gp/product/B004J3V90Y', 'NN'), 4),
#  (('consumer', 'NN'), 3),
#  (('megapixel', 'NN'), 3),
#  (('portrait', 'NN'), 3),
#  (('scenes', 'NNS'), 3),
#  (('objects', 'NNS'), 3),
#  (('weather', 'NN'), 3),
#  (('Av', 'NNP'), 3),
#  (('top', 'NN'), 3),
#  (('Custom', 'NNP'), 3),
#  (('Function', 'NNP'), 3),
#  (('macro', 'NN'), 3),
#  (('store', 'NN'), 3),
#  (('improvement', 'NN'), 3),
#  (('thumb', 'NN'), 3),
#  (('Note', 'NN'), 3),
#  (('games', 'NNS'), 3),
#  (('kind', 'NN'), 3),
#  (('Ease', 'NNP'), 3),
#  (('room', 'NN'), 3),
#  (('capture', 'NN'), 3),
#  (('move', 'NN'), 3),
#  (('PICTURES', 'NNP'), 3),
#  (('park', 'NN'), 3),
#  (('manual', 'NN'), 3),
#  (('SmugMug', 'NNP'), 3),
#  (('heart', 'NN'), 3),
#  (('content', 'NN'), 3),
#  (('juice', 'NN'), 3),
#  (('solution', 'NN'), 3),
#  (('ground', 'NN'), 3),
#  (('distance', 'NN'), 3),
#  (('outdoors', 'NNS'), 3),
#  (('adjustments', 'NNS'), 3),
#  (('records', 'NNS'), 3),
#  (('minimum', 'NN'), 3),
#  (('baby', 'NN'), 3),
#  (('adapter', 'NN'), 3),
#  (('Awesome', 'NNP'), 3),
#  (('selection', 'NN'), 3),
#  (('youtube', 'NN'), 3),
#  (('firmware', 'NN'), 3),
#  (('Powershot', 'NNP'), 3),
#  (('future', 'NN'), 3),
#  (('plus', 'NN'), 3),
#  (('SO', 'NNP'), 3),
#  (('dollars', 'NNS'), 3),
#  (('sites', 'NNS'), 3),
#  (('idea', 'NN'), 3),
#  (('JPG', 'NNP'), 3),
#  (('process', 'NN'), 3),
#  (('jump', 'NN'), 3),
#  (('brother', 'NN'), 3),
#  (('GB', 'NNP'), 3),
#  (('Speedlite', 'NNP'), 3),
#  (('thousands', 'NNS'), 3),
#  (('digital', 'NN'), 3),
#  (('AND', 'NNP'), 3),
#  (('effort', 'NN'), 3),
#  (('help', 'NN'), 3),
#  (('reviewers', 'NNS'), 3),
#  (('front', 'NN'), 3),
#  (('Battery', 'NNP'), 3),
#  (('mics', 'NNS'), 3),
#  (('stereo', 'NN'), 3),
#  (('left', 'NN'), 3),
#  (('HDMI', 'NNP'), 3),
#  (('surprise', 'NN'), 3),
#  (('laptop', 'NN'), 3),
#  (('package', 'NN'), 3),
#  (('photographs', 'NN'), 3),
#  (('purpose', 'NN'), 3),
#  (('MY', 'NNP'), 3),
#  (('stills', 'NNS'), 3),
#  (('hesitation', 'NN'), 3),
#  (('direction', 'NN'), 3),
#  (('excels', 'NNS'), 3),
#  (('owner', 'NN'), 3),
#  (('Speedlight', 'NNP'), 3),
#  (('P', 'NNP'), 3),
#  (('Mark', 'NNP'), 3),
#  (('Extreme', 'NNP'), 3),
#  (('crop', 'NN'), 3),
#  (('DSLR', 'NN'), 3),
#  (('Im', 'NNP'), 3),
#  (('Highly', 'NNP'), 3),
#  (('link', 'NN'), 3),
#  (('Aperture', 'NNP'), 3),
#  (('f/1.8', 'NN'), 3),
#  (('mirror', 'NN'), 3),
#  (('GREAT', 'NNP'), 3),
#  (('cam', 'NN'), 3),
#  (('device', 'NN'), 3),
#  (('couple', 'NN'), 3),
#  (('PEN', 'NNP'), 3),
#  (('lense', 'NN'), 3),
#  (('technology', 'NN'), 3),
#  (('knowledge', 'NN'), 3),
#  (('recommendation', 'NN'), 3),
#  (('skill', 'NN'), 3),
#  (('gear', 'NN'), 3),
#  (('glance', 'NN'), 3),
#  (('T3I', 'NNP'), 3),
#  (('mm', 'NN'), 3),
#  (('techniques', 'NNS'), 3),
#  (('tone', 'NN'), 3),
#  (('project', 'NN'), 3),
#  (('making', 'NN'), 3),
#  (('t2i', 'NN'), 3),
#  (('schedule', 'NN'), 3),
#  (('basketball', 'NN'), 3),
#  (('information', 'NN'), 3),
#  (('nikon', 'NN'), 3),
#  (('Quality', 'NN'), 3),
#  (('Class', 'NN'), 3),
#  (('Class', 'NNP'), 3),
#  (('blurry', 'NN'), 3),
#  (('girl', 'NN'), 3),
#  (('XT', 'NNP'), 3),
#  (('functionality', 'NN'), 3),
#  (('while', 'NN'), 3),
#  (('ISOs', 'NNP'), 3),
#  (('directions', 'NNS'), 3),
#  (('summer', 'NN'), 3),
#  (('design', 'NN'), 3),
#  (('Processor', 'NNP'), 3),
#  (('viewing', 'NN'), 3),
#  (('Dual-layer', 'NNP'), 3),
#  (('JPEGs', 'NNP'), 3),
#  (('IN', 'NNP'), 3),
#  (('Mac', 'NNP'), 3),
#  (('trip', 'NN'), 3),
#  (('Effect', 'NNP'), 3),
#  (('limit', 'NN'), 3),
#  (('terms', 'NNS'), 3),
#  (('+', 'NNP'), 3),
#  (('>', 'NNP'), 3),
#  (('swfWidth', 'NN'), 3),
#  (('swfHeight', 'NN'), 3),
#  (('flashParams', 'NNS'), 3),
#  (('v', 'NNP'), 3),
#  (('ffVersion', 'NN'), 3),
#  (('BottomLeft,130', 'NNP'), 3),
#  (('-12_CR0,0,0,0_.png', 'NNP'), 3),
#  (('=', 'NN'), 3),
#  (('CONS', 'NN'), 3),
#  (('CAMERA', 'NNP'), 3),
#  (('T1i', 'NNP'), 3),
#  (('layout', 'NN'), 3),
#  (('base', 'NN'), 3),
#  (('flexibility', 'NN'), 3),
#  (('vacations', 'NNS'), 3),
#  (('switch', 'NN'), 3),
#  (('d5100', 'NN'), 3),
#  (('THIS', 'NNP'), 3),
#  (('shelf', 'NN'), 3),
#  (('industry', 'NN'), 3),
#  (('packaging', 'NN'), 3),
#  (('BUT', 'NNP'), 3),
#  (('rebel', 'NN'), 3),
#  (('firing', 'NN'), 2),
#  (('in-camera', 'NN'), 2),
#  (('processing', 'NN'), 2),
#  (('upgrades', 'NNS'), 2),
#  (('rear', 'NN'), 2),
#  (('Button', 'NNP'), 2),
#  (('Feature', 'NNP'), 2),
#  (('descriptions', 'NNS'), 2),
#  (('Quality', 'NNP'), 2),
#  (('areas', 'NNS'), 2),
#  (('Spot', 'NNP'), 2),
#  (('shares', 'NNS'), 2),
#  (('wildlife', 'NN'), 2),
#  (('shooter', 'NN'), 2),
#  (('Construction', 'NN'), 2),
#  (('prices', 'NNS'), 2),
#  (('polycarbonate', 'NN'), 2),
#  (('sensitivity', 'NN'), 2),
#  (('word', 'NN'), 2),
#  (('tests', 'NNS'), 2),
#  (('score', 'NN'), 2),
#  (('Dial', 'NNP'), 2),
#  (('matter', 'NN'), 2),
#  (('Program', 'NNP'), 2),
#  (('sufficient', 'NN'), 2),
#  (('Tv', 'NNP'), 2),
#  (('ebooks', 'NNS'), 2),
#  (('//www.amazon.com/gp/product/B004PLNMR8', 'NN'), 2),
#  (('Experience', 'NNP'), 2),
#  (('World', 'NNP'), 2),
#  (('walk', 'NN'), 2),
#  (('output', 'NN'), 2),
#  (('pentaprism', 'NN'), 2),
#  (('CF', 'NNP'), 2),
#  (('Battery', 'NN'), 2),
#  (('area', 'NN'), 2),
#  (('parties', 'NNS'), 2),
#  (('result', 'NN'), 2),
#  (('sync', 'NN'), 2),
#  (('Again', 'NNP'), 2),
#  (('plunge', 'NN'), 2),
#  (('consideration', 'NN'), 2),
#  (('FAST', 'NNP'), 2),
#  (('BEAUTIFUL', 'NNP'), 2),
#  (('CLEAR', 'NNP'), 2),
#  (('KIT', 'NNP'), 2),
#  (('LENS', 'NNP'), 2),
#  (('etc.', 'NN'), 2),
#  (('BATTERY', 'NNP'), 2),
#  (('LIFE', 'NNP'), 2),
#  (('story', 'NN'), 2),
#  (('pocket', 'NN'), 2),
#  (('brain', 'NN'), 2),
#  (('morning', 'NN'), 2),
#  (('hours', 'NNS'), 2),
#  (('sort', 'NN'), 2),
#  (('bunch', 'NN'), 2),
#  (('SCREEN', 'NNP'), 2),
#  (('memories', 'NNS'), 2),
#  (('UPDATE', 'NN'), 2),
#  (('AWESOME', 'NNP'), 2),
#  (('GOT', 'NNP'), 2),
#  (('BETTER', 'NNP'), 2),
#  (('A/C', 'NNP'), 2),
#  (('annoying', 'NN'), 2),
#  (('sorts', 'NNS'), 2),
#  (('Use', 'NNP'), 2),
#  (('Eye-Fi', 'NNP'), 2),
#  (('blah', 'NN'), 2),
#  (('ME', 'NNP'), 2),
#  (('maintenance', 'NN'), 2),
#  (('comparison', 'NN'), 2),
#  (('Body', 'NNP'), 2),
#  (('usage', 'NN'), 2),
#  (('AF-S', 'NNP'), 2),
#  (('DX', 'NNP'), 2),
#  (('VR', 'NNP'), 2),
#  (('Nikkor', 'NNP'), 2),
#  (('types', 'NNS'), 2),
#  (('consumption', 'NN'), 2),
#  (('practice', 'NN'), 2),
#  (('Manual', 'NNP'), 2),
#  (('Focus', 'NNP'), 2),
#  (('item', 'NN'), 2),
#  (('delays', 'NNS'), 2),
#  (('chip', 'NN'), 2),
#  (('Patriot', 'NNP'), 2),
#  (('T2i', 'NN'), 2),
#  (('liking', 'NN'), 2),
#  (('USB', 'NNP'), 2),
#  (('fly', 'NN'), 2),
#  (('thoughts', 'NNS'), 2),
#  (('manuals', 'NNS'), 2),
#  (('Research', 'NNP'), 2),
#  (('Flickr', 'NNP'), 2),
#  (('advice', 'NN'), 2),
#  (('data', 'NNS'), 2),
#  (('space', 'NN'), 2),
#  (('object', 'NN'), 2),
#  (('convenience', 'NN'), 2),
#  (('USM', 'NNP'), 2),
#  (('towards', 'NNS'), 2),
#  (('A-1', 'NNP'), 2),
#  (('sample', 'NN'), 2),
#  (('lapse', 'NN'), 2),
#  (('HAVE', 'NNP'), 2),
#  (('cost', 'NN'), 2),
#  (('OR', 'NNP'), 2),
#  (('Zeikos', 'NNP'), 2),
#  (('surface', 'NN'), 2),
#  (('slot', 'NN'), 2),
#  (('SDXC', 'NNP'), 2),
#  (('list', 'NN'), 2),
#  (('simulation', 'NN'), 2),
#  (('inch', 'NN'), 2),
#  (('sun', 'NN'), 2),
#  (('setup', 'NN'), 2),
#  (('asset', 'NN'), 2),
#  (('frustration', 'NN'), 2),
#  (('skills', 'NNS'), 2),
#  (('progress', 'NN'), 2),
#  (('face', 'NN'), 2),
#  (('description', 'NN'), 2),
#  (('My', 'NNP'), 2),
#  (('owners', 'NNS'), 2),
#  (('starts', 'NNS'), 2),
#  (('specifications', 'NNS'), 2),
#  (('specs', 'NN'), 2),
#  (('variety', 'NN'), 2),
#  (('info', 'NN'), 2),
#  (('Grip', 'NNP'), 2),
#  (('accessory', 'NN'), 2),
#  (('tray', 'NN'), 2),
#  (('pinch', 'NN'), 2),
#  (('source', 'NN'), 2),
#  (('DC', 'NNP'), 2),
#  (('coupler', 'NN'), 2),
#  (('port', 'NN'), 2),
#  (('knob', 'NN'), 2),
#  (('wind', 'NN'), 2),
#  (('production', 'NN'), 2),
#  (('interviews', 'NNS'), 2),
#  (('Rode', 'NNP'), 2),
#  (('adapters', 'NNS'), 2),
#  (('timer', 'NN'), 2),
#  (('TV', 'NN'), 2),
#  (('street', 'NN'), 2),
#  (('heat', 'NN'), 2),
#  (('clip', 'NN'), 2),
#  (('lengths', 'NNS'), 2),
#  (('program', 'NN'), 2),
#  (('bonus', 'NN'), 2),
#  (('NOT', 'NNP'), 2),
#  (('set', 'NN'), 2),
#  (('newbie', 'NN'), 2),
#  (('D-SLRs', 'NNP'), 2),
#  (('gun', 'NN'), 2),
#  (('compact', 'NN'), 2),
#  (('ultrazoom', 'NN'), 2),
#  (('HS10', 'NNP'), 2),
#  (('sunlight', 'NN'), 2),
#  (('half', 'NN'), 2),
#  (('conditions', 'NNS'), 2),
#  (('highlights', 'NNS'), 2),
#  (('Priority', 'NNP'), 2),
#  (('hair', 'NN'), 2),
#  (('contrast', 'NN'), 2),
#  (('default', 'NN'), 2),
#  (('leap', 'NN'), 2),
#  (('items', 'NNS'), 2),
#  (('trigger', 'NN'), 2),
#  (('buy', 'NN'), 2),
#  (('motor', 'NN'), 2),
#  (('surfer', 'NN'), 2),
#  (('business', 'NN'), 2),
#  (('Nikons', 'NNS'), 2),
#  (('penny', 'NN'), 2),
#  (('past', 'NN'), 2),
#  (('Sorry', 'NNP'), 2),
#  (('recommend', 'NN'), 2),
#  (('depth', 'NN'), 2),
#  (('floor', 'NN'), 2),
#  (('ring', 'NN'), 2),
#  (('sigma', 'NN'), 2),
#  (('section', 'NN'), 2),
#  (('mistakes', 'NNS'), 2),
#  (('PS', 'NNP'), 2),
#  (('blur', 'NN'), 2),
#  (('a55', 'NN'), 2),
#  (('mirrorless', 'NN'), 2),
#  (('priority', 'NN'), 2),
#  (('accurate', 'NN'), 2),
#  (('Images', 'NNS'), 2),
#  (('sunset', 'NN'), 2),
#  (('crisp', 'NN'), 2),
#  (('child', 'NN'), 2),
#  (('DV', 'NNP'), 2),
#  (('devices', 'NNS'), 2),
#  (('NEX', 'NNP'), 2),
#  (('dpreview.com', 'NN'), 2),
#  (('Christmas', 'NNP'), 2),
#  (('members', 'NNS'), 2),
#  (('Nex', 'NNP'), 2),
#  (('hope', 'NN'), 2),
#  (('E-PL2', 'NNP'), 2),
#  (('enthusiast', 'NN'), 2),
#  (('interaction', 'NN'), 2),
#  (('pros', 'NNS'), 2),
#  (('brands', 'NNS'), 2),
#  (('categories', 'NNS'), 2),
#  (('Panasonic', 'NNP'), 2),
#  (('Kodak', 'NNP'), 2),
#  (('bells', 'NNS'), 2),
#  (('whistles', 'NNS'), 2),
#  (('e', 'NN'), 2),
#  (('places', 'NNS'), 2),
#  (('D', 'NNP'), 2),
#  (('tool', 'NN'), 2),
#  (('pain', 'NN'), 2),
#  (('buyer', 'NN'), 2),
#  (('wall', 'NN'), 2),
#  (('close-ups', 'NNS'), 2),
#  (('dialogues', 'NNS'), 2),
#  (('eBay', 'NN'), 2),
#  (('rig', 'NN'), 2),
#  (('Magic', 'NNP'), 2),
#  (('Lantern', 'NNP'), 2),
#  (('Tripod', 'NNP'), 2),
#  (('background', 'NN'), 2),
#  (('corner', 'NN'), 2),
#  (('distortion', 'NN'), 2),
#  (('positions', 'NNS'), 2),
#  (('DVD', 'NNP'), 2),
#  (('High', 'NNP'), 2),
#  (('Kit', 'NNP'), 2),
#  (('lesson', 'NN'), 2),
#  (('book', 'NN'), 2),
#  (('internet', 'NN'), 2),
#  (('experiment', 'NN'), 2),
#  (('Was', 'NNP'), 2),
#  (('father', 'NN'), 2),
#  (('boys', 'NNS'), 2),
#  (('baseball', 'NN'), 2),
#  (('water', 'NN'), 2),
#  (('L', 'NNP'), 2),
#  (('christmas', 'NN'), 2),
#  (('pace', 'NN'), 2),
#  (('tech', 'NN'), 2),
#  (('ups', 'NNS'), 2),
#  (('grain', 'NN'), 2),
#  (('Ca', 'NNP'), 2),
#  (('author', 'NN'), 2),
#  (('club', 'NN'), 2),
#  (('filmmakers', 'NNS'), 2),
#  (('CineStyle', 'NNP'), 2),
#  (('chance', 'NN'), 2),
#  (('abilities', 'NNS'), 2),
#  (('hobby', 'NN'), 2),
#  (('delivery', 'NN'), 2),
#  (('art', 'NN'), 2),
#  (('Philadelphia', 'NNP'), 2),
#  (('Zoo', 'NNP'), 2),
#  (('rates', 'NNS'), 2),
#  (('VGA', 'NNP'), 2),
#  (('reflection', 'NN'), 2),
#  (('reduction', 'NN'), 2),
#  (('multi', 'NN'), 2),
#  (('coating', 'NN'), 2),
#  (('high-transparency', 'NN'), 2),
#  (('Compatibility', 'NN'), 2),
#  (('SD/SDHC/SDXC', 'NNP'), 2),
#  (('enlargements', 'NNS'), 2),
#  (('crops', 'NNS'), 2),
#  (('first-class', 'NN'), 2),
#  (('technologies', 'NNS'), 2),
#  (('efficiency', 'NN'), 2),
#  (('T2I', 'NNP'), 2),
#  (('Crop', 'NNP'), 2),
#  (('Enhanced', 'NNP'), 2),
#  (('high-precision', 'NN'), 2),
#  (('ratio', 'NN'), 2),
#  (('machine', 'NN'), 2),
#  (('Rebels', 'NNP'), 2),
#  (('controller', 'NN'), 2),
#  (('definition', 'NN'), 2),
#  (('ratings', 'NNS'), 2),
#  (('Copyright', 'NNP'), 2),
#  (('Information', 'NNP'), 2),
#  (('sharpness', 'NN'), 2),
#  (('lab', 'NN'), 2),
#  (('files', 'NNS'), 2),
#  (('cruise', 'NN'), 2),
#  (('mountain', 'NN'), 2),
#  (('Costco', 'NNP'), 2),
#  (('bucks', 'NNS'), 2),
#  (('Ti3', 'NNP'), 2),
#  (('shopping', 'NN'), 2),
#  (('Everything', 'NNP'), 2),
#  (('ifrm', 'NN'), 2),
#  (('h2', 'NN'), 2),
#  (('catch', 'NN'), 2),
#  (('err', 'NN'), 2),
#  (('clipDiv', 'NN'), 2),
#  (('px', 'NN'), 2),
#  (('videoPlaceholder', 'NN'), 2),
#  (('fp_rewriteDiv', 'NN'), 2),
#  (('divName', 'NN'), 2),
#  (('nsPrefix', 'NN'), 2),
#  (('alert', 'NN'), 2),
#  (('code', 'NN'), 2),
#  (('cv_mo12FP77FNBABNRrefresh_preplay', 'NN'), 2),
#  (('var', 'NN'), 2),
#  (('cv_mo12FP77FNBABNRloadSwf_Core', 'NN'), 2),
#  (('swfParams', 'NNS'), 2),
#  (('pts', 'NNS'), 2),
#  (('parseFloat', 'NN'), 2),
#  (('height', 'NN'), 2),
#  (('width', 'NN'), 2),
#  (('cv_mo12FP77FNBABNRso.write', 'NN'), 2),
#  (('cv_mo12FP77FNBABNRflashcontent', 'NN'), 2),
#  (('>', 'NN'), 2),
#  (('target=', 'NN'), 2),
#  (('Player', 'NNP'), 2),
#  (('_cv_mo12FP77FNBABNRloadSwf', 'NNP'), 2),
#  (('FFFFFF', 'NNP'), 2),
#  (('LT', 'NNP'), 2),
#  (('m2X62FFJZ5RAAT', 'NN'), 2),
#  (("'cv_mo12FP77FNBABNRduration", 'NNP'), 2),
#  (('cv_mo12FP77FNBABNRnewHeight', 'NN'), 2),
#  (('w', 'NN'), 2),
#  (('bw', 'NN'), 2),
#  (('cc', 'NN'), 2),
#  (('cv_mo12FP77FNBABNRpreplay', 'NN'), 2),
#  (('cv_mo12FP77FNBABNRpreplay.src', 'NN'), 2),
#  (('logTag', 'NN'), 2),
#  (('cv_mo12FP77FNBABNRcurrentClick', 'NN'), 2),
#  (('bulky', 'NN'), 2),
#  (('interview', 'NN'), 2),
#  (('WITH', 'NNP'), 2),
#  (('tamron', 'NN'), 2),
#  (('stabilizer', 'NN'), 2),
#  (('attachment', 'NN'), 2),
#  (('sister', 'NN'), 2),
#  (('traveler', 'NN'), 2),
#  (('aspects', 'NNS'), 2),
#  (('taxes', 'NNS'), 2),
#  (('speeds', 'NNS'), 2),
#  (('f1.8', 'NN'), 2),
#  (('composition', 'NN'), 2),
#  (('recordings', 'NNS'), 2),
#  (('presets', 'NNS'), 2),
#  (('favor', 'NN'), 2),
#  (('chore', 'NN'), 2),
#  (('vacation', 'NN'), 2),
#  (('company', 'NN'), 2),
#  (('A1', 'NNP'), 2),
#  (('run', 'NN'), 2),
#  (('HUGE', 'NNP'), 2),
#  (('Elph', 'NNP'), 2),
#  (('state', 'NN'), 2),
#  (('news', 'NN'), 2),
#  (('lack', 'NN'), 2),
#  (('sentence', 'NN'), 2),
#  (('thinking', 'NN'), 2),
#  (('hype', 'NN'), 2),
#  (('CEO', 'NNP'), 2),
#  (('buying', 'NN'), 2),
#  (('tons', 'NNS'), 2),
#  (('Maui', 'NNP'), 2),
#  (('No', 'NNP'), 2),
#  (('dust', 'NN'), 2),
#  (('films', 'NNS'), 2),
#  (('piece', 'NN'), 2),
#  (('promotion', 'NN'), 2),
#  (('LOVE', 'NNP'), 2),
#  (('BEING', 'NNP'), 2),
#  (('ABLE', 'NNP'), 2),
#  ...]

# %%
tag_freq.plot(30)

# %%
#write result into .txt file
with open('POS_output.txt','w', encoding="utf-8") as f:
    for (word,tag),frequency in sorted_tag_freq:
        f.write(str(word)+'\t'+str(tag)+'\t'+str(frequency)+'\n')

# %% [markdown]
# All done！Take a look at the file you just created!
